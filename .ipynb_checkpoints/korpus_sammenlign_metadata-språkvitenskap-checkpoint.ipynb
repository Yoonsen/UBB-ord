# %% [markdown]
# # Undersøk korpus med metadata
#
# Notebook for å undersøke korpus med metadata

# %%
# aktiver den her cellen for å få siste versjon av nbtext
import module_update

# %%
import nbtext as nb
from nbtext import Corpus
# %matplotlib inline

# %% [markdown]
# Kommandoen for å lage et korpus er *Corpus()* som bygger et korpus av tekster som sammenlignes med en referanse. I det her eksemplet bygges referansen samtidig, men i et ideelt tilfelle kan vi ønske å la referansen være ferdigbygd et sted. Systemet for webdewey er [her](http://deweysearchno.pansoft.de/webdeweysearch/index.html)

# %%
objekt = Corpus(
    period=(1950, 2010),
    title='%',
    subject='kjemi',
    #ddk='%',
    reference=50,
    max_books=50)

# %% [markdown]
# ## Undersøk forskjeller
#
# Dataene viser forskjellem mellom målkorpus og referanse. Se på differansen med kommandoen *difference* som tar et sett parametre. De viktigste for analysen er *freq_exp* som vekter frekvensen til ordene i målkorpuset, og *doc_exp* som vekter dokumentfrekvensen i målkorpuset.
#
# Settes verdien for *top* lik null får du hele korpuset.

# %%
objekt.difference(top=10, aslist=False, freq_exp=1.1, doc_exp=1.5)
# Out:
#          diff
# +    0.031781
# H    0.027705
# O    0.027357
# CH   0.027125
# mol  0.026507
# C    0.026478
# OH   0.026141
# M    0.025866
# K    0.025587
# °    0.024865

# %%
objekt.difference(top=150)
# Out:
# mol, CH, +, OH, ml, NH, HCI, Fe, Na, Cu, aq, syre, Cl, reaksjon, Ag, reaksjonen, Ca, Zn, reaksjoner, base, Br, NO, inneholder, NaOH, O, stoff, dannes, IO, kjemiske, H, stoffene, reagerer, kjemisk, Mg, kjemi, S0, Cr, Hg, egenskaper, molekyler, oksygen, løsning, M, likevekt, energi, Pb, syrer, elektroner, kJ, ►, K, C, acid, ioner, Chemistry, konsentrasjonen, reaction, forbindelser, COOH, pH, stoffer, °, stoffet, raskt, C0, N0, reagere, mmol, Sn, væske, ionene, saltsyre, trykk, II, dannet, 1000, ppm, hydrogen, grunnstoffene, NMR, Cd, gass, karbon, ion, vanligvis, AH, vann, består, grunnstoff, ammoniakk, PO, protein, AG, basisk, løsningen, baser, NaCl, grunnstoffet, Mn, danne, bindinger, løses, methods, chemistry, SO, brukes, grunnstoffer, hydrokarboner, analysis, 0.05, Navn, Reaksjonen, method, prøven, konsentrert, Figure, oksidasjonstall, PH, reaksjonene, temperatur, spectra, øker, salter, klor, reactions, molekylet, angis, produkter, Chem, mg, atomer, atomnummer, 0.1, Department, katalysator, konstant, molekylene, Chemical, blanding, atm, eddiksyre, 6.2, svovelsyre, løst, gr, molekyl, avtar, HI, etanol, volum

# %% [markdown]
# Legg til summary() for se litt hva korpuset inneholder

# %%
objekt.summary()
# Out:
# {'parameters': {'year': 1950,
#   'next': 60,
#   'subject': 'kjemi',
#   'ddk': '%',
#   'author': '%',
#   'title': '%',
#   'limit': 50,
#   'reference': 50},
#  'target_urn': [2014061705197,
#   2008050904005,
#   2008111404024,
#   2009031204048,
#   2011102705027,
#   2008060304092,
#   2008060200083,
#   2009030404131,
#   2012072008079,
#   2009063001012],
#  'reference urn': [2016020408215,
#   2012050708076,
#   2011062206125,
#   2014100708014,
#   2010120905027,
#   2007120704052,
#   2016101908031,
#   2008011000123,
#   2016072948001,
#   2008052304024]}

# %% [markdown]
# # Metadata for korpuset kan raskt sjekkes
#
# Pass på at ikke korpuset er for stort (mange tusen).

# %%
nb.metadata(objekt.target_urn)
# Out:
# [[2014061705197,
#   'Lauritzen, Odd',
#   1984,
#   'Kjemi for ingeniørhøgskolen',
#   'NKI-forl.;Rud : NKI-forl., 1984-1986',
#   'nob',
#   ''],
#  [2008050904005,
#   'Prytz, Milda',
#   1959,
#   'Uorganisk kjemi',
#   'Grøndahl',
#   'nob',
#   ''],
#  [2008111404024,
#   'Ellingsen, Kjerstin',
#   2001,
#   'Theoretical studies of inner- and outer-shell spectroscopy',
#   'Faculty of Science, Department of Chemistry, University of Tromsø',
#   'eng',
#   ''],
#  [2009031204048,
#   '',
#   1997,
#   'Chemistry research at Norwegian universities and colleges',
#   '',
#   'eng',
#   ''],
#  [2011102705027, '', 2002, 'Kjemien stemmer', 'Cappelen', 'nob', ''],
#  [2008060304092,
#   'Greibrokk, Tyge',
#   1987,
#   'Kromatografi',
#   'Universitetsforlaget',
#   'nob',
#   ''],
#  [2008060200083,
#   'Ringnes, Vivi',
#   1984,
#   'Hvordan sette navn på kjemiske forbindelser',
#   'Cappelen',
#   'nob',
#   ''],
#  [2009030404131,
#   'Mjaavatten, Olav',
#   1997,
#   'Fatty acid profiles as a source of information in aquaticanimals',
#   'Department of Chemistry, University of Bergen',
#   'eng',
#   ''],
#  [2012072008079,
#   'Storm, Berit',
#   2002,
#   'Kjemi for kjemiteknikere 1',
#   'Yrkeslitteratur',
#   'mul',
#   ''],
#  [2009063001012, 'Brandt, Tor', 1978, 'Naturfag', 'Aschehoug', 'nob', ''],
#  [2014062548106,
#   'Jansson, Erik',
#   2008,
#   'Reguleringsteknikk',
#   'Gyldendal undervisning',
#   'nob',
#   ''],
#  [2008022900057,
#   'Boye, Nils Chr.',
#   1995,
#   'Kjemi og miljølære',
#   'Universitetsforl.',
#   'nob',
#   ''],
#  [2013070205129,
#   'Boye, Nils Chr.',
#   1986,
#   'Kjemi for ingeniører',
#   'Universitetsforl.;Oslo : Universitetsforl., cop. 1986-1987',
#   'nob',
#   ''],
#  [2013121008070,
#   'Wijkmark, Carl-Henning',
#   2007,
#   'moderne døden',
#   'Arneberg forl.',
#   'nob',
#   'swe'],
#  [2016060608146,
#   'Ektvedt, Inger Johanne',
#   1978,
#   'Kjemi',
#   'Universitetsforlaget',
#   'nob',
#   ''],
#  [2011010508068,
#   'Danielsen, Knut',
#   1996,
#   '¹H and ¹³C NMR spectroscopic, chromatographic and synthetic studies of anthraquinones',
#   'Department of Chemistry, University of Bergen',
#   'eng',
#   ''],
#  [2010021504010,
#   '',
#   1997,
#   'Kjemien stemmer',
#   'Cappelen;Oslo : Cappelen, c1997',
#   'nob',
#   ''],
#  [2007072401090,
#   'Lund, Einar Wang',
#   1977,
#   'Kjemiske formler og data',
#   'Universitetsforlaget',
#   'nob',
#   ''],
#  [2008060400040, 'Hauge, Jens G.', 1985, 'Biokjemi', 'Tano', 'nob', ''],
#  [2016072808066,
#   'Ringnes, Vivi',
#   1988,
#   'Periodesystemet og grunnstoffnavnene',
#   '',
#   'nob',
#   ''],
#  [2014042906108,
#   '',
#   1983,
#   'Håndtering av kjemikalier',
#   'Nordkjemi',
#   'nob',
#   ''],
#  [2008071004061, 'Brandt, Tor', 1986, 'Kjemi 3KJ', 'Aschehoug', 'nob', ''],
#  [2008061000020,
#   '',
#   1989,
#   'Vitenskapens verden',
#   'Norsk Fogtdal A/S;[Oslo] : Norsk Fogtdal A/S, cop. 1987-1991',
#   'nob',
#   'eng'],
#  [2007110601031, 'Kofstad, Per', 1992, 'Uorganisk kjemi', 'TANO', 'nob', ''],
#  [2008011800055,
#   'Hokland, Bjørn M.',
#   1994,
#   'Klinisk kjemi og fysiologi',
#   'Universitetsforl.',
#   'nob',
#   ''],
#  [2012053108121,
#   'Holtan, Hans',
#   1971,
#   'Kjemisk reaksjonskinetikk',
#   'Universitetsforlaget',
#   'nob',
#   ''],
#  [2008053004003,
#   'Roald, Arnvid S.',
#   1980,
#   'Miljø, kjemi, ressurser',
#   'Universitetsforlaget',
#   'nob',
#   ''],
#  [2009101204034, 'Sire, Jan', 1995, 'Chemica data', 'Fagbokforl.', 'nob', ''],
#  [2008010704007,
#   'Lauritzen, Odd',
#   1993,
#   'Kjemi for forkurset',
#   'NKI',
#   'nob',
#   ''],
#  [2010080208019, '', 1996, 'Klinisk biokjemi', 'Alma mater', 'nob', ''],
#  [2008110604044,
#   'Halvorsen, Ragnar',
#   2000,
#   'Dyno industrier',
#   'Dyno',
#   'nob',
#   ''],
#  [2015111908086,
#   '',
#   2006,
#   'Klinisk biokjemi og fysiologi',
#   'Gyldendal akademisk',
#   'nob',
#   ''],
#  [2011080306085,
#   '',
#   2004,
#   'Treffsikker nettbasert læring?',
#   'Norgesuniversitetet',
#   'nob',
#   ''],
#  [2007071800018,
#   '',
#   1984,
#   'Kartotek for kjemiske stoffer',
#   'Vita-data;Trondheim : Vita-data, 1984',
#   'nob',
#   ''],
#  [2011062806125,
#   'Hagelin, Gunnar',
#   1987,
#   'Buffere i kjemi',
#   'Universitetsforlaget',
#   'nob',
#   ''],
#  [2015090108150,
#   'Hammer, Kristin',
#   1997,
#   'Stereoselektive synteser av konformasjonbegrensende α-aminosyrederivater',
#   'Kjemisk institutt, Universitetet i Oslo',
#   'mul',
#   ''],
#  [2013012205069,
#   'Steen, Bjørn-Gunnar',
#   2006,
#   'Himmelsk kjemi',
#   'Høyskoleforl.',
#   'nob',
#   ''],
#  [2011080106058,
#   'Sjøberg, Nils Olav',
#   2004,
#   'Kort og godt kjemi',
#   'Vett &amp; viten',
#   'nob',
#   ''],
#  [2009062901024, '', 2001, 'Kjemien stemmer', 'Cappelen', 'nob', ''],
#  [2012102206008,
#   "D'Anna, Barbara",
#   2001,
#   'Laboratory studies of the oxidation mechanisms of aldehydes in the atmosphere',
#   'Department of Chemistry, Faculty of Mathematics and Natural Sciences, University of Oslo',
#   'eng',
#   ''],
#  [2009011400008,
#   'Frengstad, Bjørn',
#   2002,
#   'Groundwater quality of crystalline bedrock aquifers in Norway',
#   'Department of Geology and Mineral Resources Engineering, Norwegian University of Science and Technology',
#   'eng',
#   ''],
#  [2016030308072,
#   'Palmer, Herbert',
#   1992,
#   'Utviklingen av den kliniske kjemi i Norge',
#   'Norsk selskap for klinisk kjemi og klinisk fysiologi',
#   'nob',
#   ''],
#  [2011041208080,
#   '',
#   2004,
#   'Brukerhåndbok i klinisk kjemi',
#   'Akademisk fagforl.',
#   'nob',
#   ''],
#  [2012110706216,
#   'Courivaud, Frédéric',
#   1999,
#   'pulsed field gradient NMR study of molecular diffusion in the mesoporous MCM-41',
#   'Department of Chemistry, Faculty of Mathematics and Natural Sciences, University of Oslo;Unipub',
#   'eng',
#   ''],
#  [2012101906080,
#   'Øiestad, Elisabeth Leere',
#   2000,
#   'Proton transfer reactions and reactions of protonated molecules studied in the gas phase',
#   'Department of Chemistry, Faculty of Mathematics and Natural Sciences, University of Oslo;Unipub',
#   'eng',
#   ''],
#  [2016070808154,
#   'Liu, Huiling',
#   2001,
#   'Chemo-enzymatic synthesis of enantiopure fine chemicals and drugs',
#   'Norwegian University of Science and Technology, Faculty of Chemistry and Biology, Department of Chemistry',
#   'eng',
#   ''],
#  [2016082308122,
#   'Stordrange, Laila',
#   2003,
#   'Multivariate analysis of near-infrared spectroscopic data from reaction monitoring',
#   'Department of Chemistry, University of Bergen',
#   'eng',
#   ''],
#  [2014110407663,
#   'Langford, Michael J.',
#   1981,
#   'Teknologisk forlags store bok om mørkeromsarbeid',
#   'Teknologisk forlag',
#   'nob',
#   'eng'],
#  [2007121301014,
#   'Olsen, Odd Arild',
#   1994,
#   'Miljøovervåking',
#   'Tapir',
#   'nob',
#   ''],
#  [2008090204050,
#   'Boye, Nils Chr.',
#   1999,
#   'Fasit med kommentarer til Kjemi og miljølære, del 1 Kjemi, og Kjemi for ingeniører 1 - Grunnlag',
#   'Universitetsforl.',
#   'nob',
#   '']]

# %% [markdown]
# ### Søk etter sett av ord i clustret
#
# Finn verdien for ord i clusteret med objekt.check_words('o1 o2 o3 ... oN') med opsjonell spesifikasjon av eksponent. Bare list ordene opp med mellomrom, ord som ikke er i clusteret vil heller ikke vises. Alle andre vises med assosiasjonsverdien og sorteres var høy til lav. Tittel på kolonnen gir en påminnelse om ordet listen er kollokert fra.

# %%
objekt.search_words( 'bunzen bunsen petroleum lakmus kolbe . og ,')
# Out:
#                diff
# lakmus     0.303639
# kolbe      0.266608
# petroleum  0.255951
# .          0.219422
# ,          0.217530
# og         0.150317

# %%
nb.cloud(objekt.difference(aslist=False, top=150))

# %%
G=nb.make_network(objekt.target_urn[0], list(objekt.difference(aslist=False, top=150).index) )

# %%
nb.draw_graph_centrality(G, fontsize=12, k=1)
# Out:
# True

# %%
nb.central_betweenness_characters(G)
# Out:
# [('H', 0.06279219031873064),
#  ('C', 0.055627966220223736),
#  ('+', 0.05235885644157913),
#  ('°', 0.038328224050228184),
#  ('O', 0.032452097089860986),
#  ('vann', 0.02666022242176756),
#  ('kjemiske', 0.021958233531792562),
#  ('mol', 0.018929286071415027),
#  ('OH', 0.01576755055123794),
#  ('K', 0.014164223361293757)]
