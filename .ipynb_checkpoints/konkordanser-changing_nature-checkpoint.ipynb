# %% [markdown]
# # Undersøk korpus med metadata og konkordans
#
# Konkordanser gir oppslagt for nøkkelord i en kontekst, også kjent under akronymet [KWIC](https://en.wikipedia.org/wiki/Key_Word_in_Context). Kommandoene som benyttes er get_konk (eller nb.get_konk), og ligger klar i modulen nbtext.
#
# Gjør API-et aktivt ved å kjøre cellen under.

# %%
import module_update

# %%
import nbtext as nb
from nbtext import get_konk, get_urnkonk, urn_from_text
# %matplotlib inline

# %% [markdown]
# ## Konkordanser
#
# Det minste som må spesifiseres for kommandoen *get_konk()* er et ord.

# %%
get_konk('arbeid')
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014021108043' target='_'>Johnsen, John G.,Norsk hermetikkmuseum,1995</a></td><td>mer enn 100 personer i</td><td>arbeid</td><td style='text-align:left'>i fabrikken . Navnet til</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014021108043' target='_'>Johnsen, John G.,Norsk hermetikkmuseum,1995</a></td><td>framstillingsmåte med hovedsaklig bare manuelt</td><td>arbeid</td><td style='text-align:left'>. Både varer og emballasje</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014021108043' target='_'>Johnsen, John G.,Norsk hermetikkmuseum,1995</a></td><td>vært så intens at annet</td><td>arbeid</td><td style='text-align:left'>i samme rom ville vært</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014021108043' target='_'>Johnsen, John G.,Norsk hermetikkmuseum,1995</a></td><td>kvinnene ble ofte innkalt til</td><td>arbeid</td><td style='text-align:left'>på kort varsel . Dette</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013120306054' target='_'>Du Maurier, Daphne,Uten hensyn,1980</a></td><td>utsultede dyr gjør ikke godt</td><td>arbeid</td><td style='text-align:left'>, sa han dristig .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013120306054' target='_'>Du Maurier, Daphne,Uten hensyn,1980</a></td><td>det var vanskehgere a finne</td><td>arbeid</td><td style='text-align:left'>enn han hadde trodd .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013120306054' target='_'>Du Maurier, Daphne,Uten hensyn,1980</a></td><td>. Han gjorde tre manns</td><td>arbeid</td><td style='text-align:left'>, og han hadde provisjon</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013120306054' target='_'>Du Maurier, Daphne,Uten hensyn,1980</a></td><td>det blir dobbelt så mye</td><td>arbeid</td><td style='text-align:left'>. Med alle de pengene</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013042206093' target='_'>Marryat, Frederick,Peter Simple,1968</a></td><td>enn å utføre hele mitt</td><td>arbeid</td><td style='text-align:left'>som en gentleman , men</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013042206093' target='_'>Marryat, Frederick,Peter Simple,1968</a></td><td>hatt noen annen utdannelse eller</td><td>arbeid</td><td style='text-align:left'>, har jeg spist sammen</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013042206093' target='_'>Marryat, Frederick,Peter Simple,1968</a></td><td>for å finne seg et</td><td>arbeid</td><td style='text-align:left'>. Først hadde hun vært</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014021307001' target='_'>Turi, Anne Lene,"Dah mupbien [sic] bealan vuartasjieh",2010</a></td><td>M . , 2008. Forebyggende</td><td>arbeid</td><td style='text-align:left'>i skolen . Om barn</td></tr>
# </table>

# %% [markdown]
# Kommandoen *get_konk()* tar parametre for å begrense søket - noen er satt opp med defaultverdier. Parametrene er en måte spesifisere et korpus på, men se nedenfor for andre måter å gjøre akkurat det på.

# %%
get_konk('arbeid', {'size':10, 'corpus':'bok', 'before':12, 'after':12, 'title':'%ordbok%norsk%'})
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010111806015' target='_'>Tønnessen, S. Juell,Retskrivningsordbok over det norske riksmaal,1910</a></td><td>aræometer ( et , ft . - e : flytevegt ) .</td><td>arbeid</td><td style='text-align:left'>( e ) ( et , ft . - r ) ;</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091205060' target='_'>Beckman, Nat.,Norsk-svensk ordbok för bokmål och nynorska,1960</a></td><td>None</td><td>arbeid</td><td style='text-align:left'>arbete - e arbeta - er arbetare - s | - hold</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091205060' target='_'>Beckman, Nat.,Norsk-svensk ordbok för bokmål och nynorska,1960</a></td><td>- korn brodsad - krumme smula - les , < ~ <</td><td>arbeid</td><td style='text-align:left'>lonlost - nid yrkesavund</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091205060' target='_'>Beckman, Nat.,Norsk-svensk ordbok för bokmål och nynorska,1960</a></td><td>ordhårda ; humoren var vel < ~ kraftig ; et ~ i</td><td>arbeid</td><td style='text-align:left'>styvt - de varaktighet; grovlek ; det var høy den og ~</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091205060' target='_'>Beckman, Nat.,Norsk-svensk ordbok för bokmål och nynorska,1960</a></td><td>5 ~ < gardiner lufter - dommer juridiskt utbildad domare - lært</td><td>arbeid</td><td style='text-align:left'>arbete som kraver yrkesskicklighet - plan undervisningsplan - verk * = bindingsverk</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091205060' target='_'>Beckman, Nat.,Norsk-svensk ordbok för bokmål och nynorska,1960</a></td><td>, svarandeombud - lig tillfredsstallande ; i ~ stand ; et ~</td><td>arbeid</td><td style='text-align:left'>dugligt</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091205060' target='_'>Beckman, Nat.,Norsk-svensk ordbok för bokmål och nynorska,1960</a></td><td>; ~ £ høyere enn alt folket ; kronede ~ r -</td><td>arbeid</td><td style='text-align:left'>hjårnarbete ; jfr hovedarbeid - fOdSel låk . huvudbjudning , då fostret</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091205060' target='_'>Beckman, Nat.,Norsk-svensk ordbok för bokmål och nynorska,1960</a></td><td>> ~ w > et</td><td>arbeid</td><td style='text-align:left'>imot et annet jåmfora ; r * > en med selskap halla</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091205060' target='_'>Beckman, Nat.,Norsk-svensk ordbok för bokmål och nynorska,1960</a></td><td>hogst , fråmst , viktigast , central o . d . -</td><td>arbeid</td><td style='text-align:left'>jfr hode-arbeid - artikkel tidnings ledare - arving * den eom får</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091205060' target='_'>Beckman, Nat.,Norsk-svensk ordbok för bokmål och nynorska,1960</a></td><td>verk av en f6rf . eller under en period ; jfr -</td><td>arbeid</td><td style='text-align:left'>None</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091205060' target='_'>Beckman, Nat.,Norsk-svensk ordbok för bokmål och nynorska,1960</a></td><td>på ~ et pantsåtta , « stampa » - and islandsknipa -</td><td>arbeid</td><td style='text-align:left'>innearbete ; hushgt arbete - arme pauvres honteux - ame huslig hard</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006120401012' target='_'>Schjøtt, Steinar,Norsk ordbok, med ordtyding paa norsk-dansk,1914</a></td><td>noko - det er altid noget som feiler ; « med slikt</td><td>arbeid</td><td style='text-align:left'>vert det alltid noko - » ( a : noget mangelfuldt )</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006120401012' target='_'>Schjøtt, Steinar,Norsk ordbok, med ordtyding paa norsk-dansk,1914</a></td><td>arbeide, slæpe , iB . uten held ; « » paa eit</td><td>arbeid</td><td style='text-align:left'>» ; ~ med ogs . bearbeide ; « han - med</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006120401012' target='_'>Schjøtt, Steinar,Norsk ordbok, med ordtyding paa norsk-dansk,1914</a></td><td>me stod - for uveret o : i ly ; faa eit</td><td>arbeid</td><td style='text-align:left'>- taa et arbeide tsersiZ til bestemt tid , Baa man kan</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006120401012' target='_'>Schjøtt, Steinar,Norsk ordbok, med ordtyding paa norsk-dansk,1914</a></td><td>1. hos , ved siden av ; 2. 8. attaat 2. -</td><td>arbeid</td><td style='text-align:left'>n leilighetsarbeide . - brend s . attaat- . - mat m</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006120401012' target='_'>Schjøtt, Steinar,Norsk ordbok, med ordtyding paa norsk-dansk,1914</a></td><td>border ( om korn ) , sml . bola seg . Bord</td><td>arbeid</td><td style='text-align:left'>n grovere snekkerarbeide . - anskjer n stort øsekar til storbaat .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006120401012' target='_'>Schjøtt, Steinar,Norsk ordbok, med ordtyding paa norsk-dansk,1914</a></td><td>det ligg i - t millom Toten og Land » . Byte</td><td>arbeid</td><td style='text-align:left'>n gjensidig arbeidshjælp . - gard ( bytes- ) m grænsegjærde .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006120401012' target='_'>Schjøtt, Steinar,Norsk ordbok, med ordtyding paa norsk-dansk,1914</a></td><td>- lag n b.lag , b . forbindelse ; s . -</td><td>arbeid</td><td style='text-align:left'>, - lina ( bytes- ) f grenselinje , delingslinje . »</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006120401012' target='_'>Schjøtt, Steinar,Norsk ordbok, med ordtyding paa norsk-dansk,1914</a></td><td>baat som ikke holder følge ; koma i - en med eit</td><td>arbeid</td><td style='text-align:left'>komme akterut med et arbeide , - bak adv : koma -</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006120401012' target='_'>Schjøtt, Steinar,Norsk ordbok, med ordtyding paa norsk-dansk,1914</a></td><td>det ut { han tok det ) paa - » . -</td><td>arbeid</td><td style='text-align:left'>n forsagtarbeide , akkord- .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006120401012' target='_'>Schjøtt, Steinar,Norsk ordbok, med ordtyding paa norsk-dansk,1914</a></td><td>Fyreaat adv forut , i forveien ,</td><td>arbeid</td><td style='text-align:left'>n forarbeide , - bera vt anføre til sin unclßkvlclniußi « han</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009112700077' target='_'>,Norsk ordbok - nynorskens leksikografiske kanon?,1997</a></td><td>Både frivillige medarbeidarar og tilsette har gjennom åra lagt ned eit stort</td><td>arbeid</td><td style='text-align:left'>i å byggje opp samlingane , og dei er det beste som</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009112700077' target='_'>,Norsk ordbok - nynorskens leksikografiske kanon?,1997</a></td><td>vore ekstraarbeid , underordna redigeringa , for dei tilsette , og ulønt</td><td>arbeid</td><td style='text-align:left'>for frivillige medhjelparar og informantar. Det er ikkje mykje tid og innsats</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009112700077' target='_'>,Norsk ordbok - nynorskens leksikografiske kanon?,1997</a></td><td>var ein Vilhelm Dale som brakte det , vi var ute på</td><td>arbeid</td><td style='text-align:left'>i saman . ( Johs . A . Dale , Meland )</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009112700077' target='_'>,Norsk ordbok - nynorskens leksikografiske kanon?,1997</a></td><td>publisering . Jeg vil i denne artikkelen kort gjøre rede før Dokumentasjonsprosjektets</td><td>arbeid</td><td style='text-align:left'>og hva databasene vil inneholde . Hovedvekten er lagt på en gjennomgang</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN

# %% [markdown]
# ### Samme konk mot aviser  (kan ta litt tid)

# %% [markdown]
# Bøker og aviser deler litt på egenskaper. Foruten årstall vil for eksempel 'title' gjøre begrensing på boktitler for bøker, og avisnavn for aviser. Årstall begrenser utgivelsesår.

# %%
get_konk('arbeid', {'size':5, 'title':'aftenposten','corpus':'avis', 'yearfrom':1950, 'yearto':1955})
# Out:
# <table><tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19550506_96_206_1' target='_'>aftenposten-19550506</a></td><td>lJ-49 " . Efter dagens</td><td>arbeid</td><td style='text-align:left'>, gå til S og</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19550506_96_206_1' target='_'>aftenposten-19550506</a></td><td>form . still , som</td><td>arbeid</td><td style='text-align:left'>, formann på verk- sted</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19550506_96_206_1' target='_'>aftenposten-19550506</a></td><td>nelse , erfaring i sosialt</td><td>arbeid</td><td style='text-align:left'>og interesse for og innsikt</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19550506_96_206_1' target='_'>aftenposten-19550506</a></td><td>regne med å få varig</td><td>arbeid</td><td style='text-align:left'>. Lonn etler regulativet for</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19550506_96_206_1' target='_'>aftenposten-19550506</a></td><td>avdelingen . Kjennskap til lonnings-</td><td>arbeid</td><td style='text-align:left'>ønskelig . I , onn</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19520103_93_3_1' target='_'>aftenposten-19520103</a></td><td>VI har 1000 flere 1</td><td>arbeid</td><td style='text-align:left'>i ftr . Men det</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19520103_93_3_1' target='_'>aftenposten-19520103</a></td><td>At redningsmannskapet utforte et førsteklasses</td><td>arbeid</td><td style='text-align:left'>, kan det ikke være</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19520103_93_3_1' target='_'>aftenposten-19520103</a></td><td>kjærlighet for Hode Kors '</td><td>arbeid</td><td style='text-align:left'>i Norge er vel kjent</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19520103_93_3_1' target='_'>aftenposten-19520103</a></td><td>. Den skildrer det mangesidige</td><td>arbeid</td><td style='text-align:left'>ombord på skipet i storm</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19520103_93_3_1' target='_'>aftenposten-19520103</a></td><td>populære romaner — 48 timers</td><td>arbeid</td><td style='text-align:left'>, 20.000 franc firtjsneste for</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_olympiaposten_null_19520214_0_1_1' target='_'>aftenposten-19520214</a></td><td>så er det det fantastiske</td><td>arbeid</td><td style='text-align:left'>som er utført her på</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_olympiaposten_null_19520214_0_1_1' target='_'>aftenposten-19520214</a></td><td>: e skiene i sitt</td><td>arbeid</td><td style='text-align:left'>for føden . Det var</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_olympiaposten_null_19520214_0_1_1' target='_'>aftenposten-19520214</a></td><td>daglig være å finne i</td><td>arbeid</td><td style='text-align:left'>, og selve det tekniske</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_olympiaposten_null_19520214_0_1_1' target='_'>aftenposten-19520214</a></td><td>i det , vet hvilket</td><td>arbeid</td><td style='text-align:left'>som ligger bak en olympiade</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_olympiaposten_null_19520214_0_1_1' target='_'>aftenposten-19520214</a></td><td>til Italia for å søke</td><td>arbeid</td><td style='text-align:left'>. — Men hvis det</td></tr>
# </table>

# %% [markdown]
# ## Bygg et korpus av bøker
#
# Får å bygge et korpus av bøker (aviser er i kjømda) brukes kommandoen *get_urn()* med nesten de samme parametrene som for *get_konk()*.
#
# Man kan også finne URN-er i bokhylla, eller lage en liste med URN-er i en tekstfil og bruke kommandoen *urn_from_text()*. Se nedenfor.

# %% [markdown]
# #### get_urn()
#
# Kommandoen *get_urn()* gir et tilfeldig utvalg bøker innenfor spesifikasjonene.
# Aktiver cellen under et par ganger for å se effekten.

# %%
nb.get_urn()
# Out:
# [[2009091400002, '', '"Leve og lære"', 1992],
#  [2009051500043, 'Thon, Ole Anton', 'Handels- og kontorarbeid', 1991],
#  [2008020104048, '', 'Alle barnas gale gåter', 1993],
#  [2010111706068, 'Nordeide, Søren', 'Læraren og lærararbeidet', 1921],
#  [2008090204060, 'Hjorth, Vigdis', 'første gangen', 1999],
#  [2009022000080, 'Haahjem, Kaare', 'Giske elverk', 1997],
#  [2014082608084, '', 'Arbeidsprogram for 1993-96', 1993],
#  [2011012706059,
#   'Wolden, Knut',
#   'Kartlegging av grusforekomster og registrering av grusuttak langs Verdalselva, Verdal kommune, Nord-Trøndelag',
#   1991],
#  [2008072404002,
#   'Byholt, Morten',
#   'Sometimes nonparametrics beat parametrics, even when the model is right',
#   1996],
#  [2015071608029,
#   'Hjersing, O.A.',
#   'Stamtavle over familien Hjersing i Norge',
#   1904]]

# %% [markdown]
# ### Med kriterier
#
# Vanligvis begrenses korpuset til et helt spesifikt sett av bøker. Fra bibliotekets metadata er både katalogiseringsdata og klassifikasjonsdata tilgjengelig, som forfatter, tittel og år, kjønn (gender), tema (subject) og Dewey (ddk).
#
# Her settes dataene opp på formen
#
#     navn = definisjon
#     navn
#
# Første linje definerer navnet, andre viser innholdet. Husk å endre *navn* når cellene kopieres!

# %%
nb.get_urn({'subject':'språk', 'ddk':'4%', 'year':1950, 'next':50, 'limit':30})
# Out:
# [[2008052104071, 'Voss, J. Fredrik', 'Norsk-tysk ordbok', 1969],
#  [2008102704056, 'Høgberg, Eva', 'Håndbok i grammatikk og språkbruk', 2000],
#  [2011050306031,
#   '',
#   'Studier i norsk språkvitenskap = Studies in Norwegian linguistics',
#   1981],
#  [2011062305011, 'Heggstad, Leiv', 'Fornorskingsordbok', 1958],
#  [2007072704027, '', 'Terminologien i norsk språklære', 1977],
#  [2010091608071,
#   'Gullichsen, Harald',
#   'Form, substans og språklig tegn',
#   1990],
#  [2011050506116, 'Eifring, Halvor', 'Høy eller stein?', 1985],
#  [2012121108021,
#   '',
#   'Studier i norsk språkvitenskap = Studies in Norwegian linguistics',
#   1993],
#  [2012012308184, 'Skard, Vemund', 'Norsk språkhistorie', 1972],
#  [2009102700081, 'Bull, Ella Holm', 'Åarjel-saemien', 1996],
#  [2007032801034, 'Hjort, J.B.', 'Sprogstridens kvintessens', 1963],
#  [2015090808124, 'Hvenekilde, Anne', 'Snakker du norsk?', 1986],
#  [2008060304064, 'Sandvei, Marius', 'Svensk-norsk ordbok', 1979],
#  [2015062308157, 'Fabricius-Hansen, Cathrine', 'Å lese tysk sakprosa', 1986],
#  [2012012308050, 'Rytter, Olav', 'Slavisk målreising', 1971],
#  [2009101600049, 'Haugen, Einar', 'Norsk engelsk ordbok', 1984],
#  [2012111305040,
#   '',
#   'Nynorsk litteraturantologi for den vidaregåande skolen',
#   1977],
#  [2007070401079, 'Strøm, Doris', 'Tysk-norsk teknisk ordbok', 1979],
#  [2010121320005, 'Skolt, Knut', 'Hemsedalsmålet', 1999],
#  [2016063008009, '', 'This way', 1972],
#  [2010062908094,
#   'Börestam Uhlmann, Ulla',
#   'Språkmöten och mötesspråk i Norden',
#   1991],
#  [2007090501045, 'Faarlund, Jan Terje', 'Morfologi', 1988],
#  [2007050404045, 'Bjerke, André', 'Dannet talesprog', 1966],
#  [2009102904098, '', 'Ordbog over det norrøne prosasprog', 1995],
#  [2010070808085,
#   'Graedler, Anne-Line',
#   'Morphological, semantic and functional aspects of English lexical borrowings in Norwegian',
#   1998],
#  [2007121800050, 'Manne, Gerd', 'Bo i Norge', 1994],
#  [2010071408105, 'Skjekkeland, Martin', 'norske dialektane', 1997],
#  [2013010808118, 'Guttorm, Ellen Marit', "Gåi'ke-miel'ki", 1975],
#  [2008060300064,
#   'Parneman, Helge',
#   'Differensiert tysk grammatikk for ungdomsskolen og den videregående skole',
#   1980],
#  [2016052708029, 'Vinje, Finn-Erik', 'Skriveregler', 1976]]

# %%
ordbøker = nb.get_urn({'ddk':'4%', 'year':1910, 'title':"%bokmålsord%", 'next':100, 'limit':30})
ordbøker
# Out:
# [[2016072548020, '', 'Bokmålsordboka', 2004],
#  [2011060308097, 'Hjulstad, Håvard', 'Bokmålsordliste', 2006],
#  [2010111508072, '', 'Bokmålsordbok', 1991],
#  [2013061906058, 'Gundersen, Dag', 'Gyldendals bokmålsordliste', 2007],
#  [2013081506040, '', 'Bokmålsordboka', 1993],
#  [2008061304034, '', 'Bokmålsordlista', 1992],
#  [2009070701034, '', 'Bokmålsordbok', 1991],
#  [2011103124042, '', 'Bokmålsordboka', 1986],
#  [2011062808148, '', 'Bokmålsordboka', 2005]]

# %% [markdown]
# ## Konkordanser med URNer
#
# Kommandoen er *get_urnkonk()* som bruker URNer i stedet for metadata.

# %%
get_urnkonk('pålegg', {'urns':ordbøker, 'before':8, 'after':8, 'size':14}, html=True)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>på 400 000 kr / heve g-n -</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>gasje re v2 gi gasje , lønn være</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>bli instruert om hva en skal gjøre få</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>om instruk s ml forskrift , ordre få</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>kabaretfat - fat oppdelt fat til småretter ,</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>o l - kunstner kabb ml kabbe (</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>til nå kan du komme inn / i</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>, befaling : du kan ( få )</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>) l-en 3 lang brødskive med flere slags</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>landgangs | bro el . - bru landgang</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>mot / - ordre / 1 - et</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>/ / - foreldrene sine / nå skal</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>) av kumelk mager m-smør særl før :</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>av innkokt myse , saup el . melk</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>rystende oppskjær - et oppskåme kjøttvarer brukt som</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>ostemasse el . innkokt myseblanding som brukes til</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>brun o - / hvit o - /</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>flere skiver med</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>mellom - element element som består av flere</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>særlig engsoleie - brød brødskive med smør og</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>- bukk ml el . - i ubf</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>til ) 1 tilholdssted 2 mest foreld :</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>, ordre - holde foreld : pålegge t</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>/ spise brødet tørt uten smør el .</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>/ slåss på t-e never slåss uten våpen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016072548020' target='_blank' style='text-decoration:none'>Bokmålsordboka, , 2004</a>
#                 </td>
#                 <td>at det blir lufttett med undertrykk v -</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>i plast - pakning lufttom emballasje , særlig</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011060308097' target='_blank' style='text-decoration:none'>Bokmålsordliste, Hjulstad, Håvard, 2006</a>
#                 </td>
#                 <td>el - er - dde - dd gi</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011060308097' target='_blank' style='text-decoration:none'>Bokmålsordliste, Hjulstad, Håvard, 2006</a>
#                 </td>
#                 <td>til båt ; lang brødskive med flere slags</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>landhandel - en - handler - handlene krambu</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011060308097' target='_blank' style='text-decoration:none'>Bokmålsordliste, Hjulstad, Håvard, 2006</a>
#                 </td>
#                 <td>maten uten det som hører til : maule</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011060308097' target='_blank' style='text-decoration:none'>Bokmålsordliste, Hjulstad, Håvard, 2006</a>
#                 </td>
#                 <td>- en - er befaling , beskjed ,</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>;</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011060308097' target='_blank' style='text-decoration:none'>Bokmålsordliste, Hjulstad, Håvard, 2006</a>
#                 </td>
#                 <td>en - er stolpe , pel , pæl</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>- et - - a el - ene</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011060308097' target='_blank' style='text-decoration:none'>Bokmålsordliste, Hjulstad, Håvard, 2006</a>
#                 </td>
#                 <td>None</td>
#                 <td>pålegg</td>
#                 <td style='text-align:left'>på brødskiva pålitelig - - e nøyaktig ,</td>

# %% [markdown]
# ## URNer fra Bokhylla
#
# Gåt til http://nb.no/search og søk etter bøker. I søkefeltet legger du til ordet 'debugon' - da kommer resultatene med URN-er. Kopier hele siden (f.eks. med ctrl-a) og lim det inn i cellen under mellom de triple hermetegnene.
#
# Etter at teksten (det blir gjerne en hel del) er limt inn og cellen er aktivert, vil URNene ligge i variabelen bokhylla_urn, som så kan brukes sammen med *get_urnkonk()*.
#
# Har du noen URNer liggende i en Word-fil eller lignende, kan det også limes inn.

# %%
bokhylla_urn = """  """
bokhylla_urn = urn_from_text(bokhylla_urn)
bokhylla_urn

# %%
get_urnkonk('Ask',{
    'urns':bokhylla_urn
})
