# %% [markdown]
# # Undersøk korpus med metadata og konkordans
#
# Konkordanser gir oppslagt for nøkkelord i en kontekst, også kjent under akronymet [KWIC](https://en.wikipedia.org/wiki/Key_Word_in_Context). Kommandoene som benyttes er get_konk (eller nb.get_konk), og ligger klar i modulen nbtext.
#
# Gjør API-et aktivt ved å kjøre cellen under.

# %%
import module_update

# %%
import nbtext as nb
from nbtext import get_konk, get_urnkonk, urn_from_text
# %matplotlib inline

# %% [markdown]
# ## Konkordanser
#
# Det minste som må spesifiseres for kommandoen *get_konk()* er et ord.

# %%
get_konk('naturen')
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014032508031' target='_'>Stubseid, Gunnar,Ungkar og spelemann,1986</a></td><td>nærast stig fram direkte frå</td><td>naturen</td><td style='text-align:left'>.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007082904009' target='_'>Skirbekk, Håvard,Bjølset og Hagen,1983</a></td><td>mangehundreårig tradisjon med utnytting av</td><td>naturen</td><td style='text-align:left'>til slått og beite .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073006042' target='_'>Kverndokken, Kåre,Litteraturundervisning,1989</a></td><td>sikkert: Mangt og meget i</td><td>naturen</td><td style='text-align:left'>skjer i rytmiske sving -</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073006042' target='_'>Kverndokken, Kåre,Litteraturundervisning,1989</a></td><td>det fine samspillet ute i</td><td>naturen</td><td style='text-align:left'>er smågnagerne nemlig helt uunnværlige</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073006042' target='_'>Kverndokken, Kåre,Litteraturundervisning,1989</a></td><td>er det best i</td><td>naturen</td><td style='text-align:left'>for fisker og sopper .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014073006042' target='_'>Kverndokken, Kåre,Litteraturundervisning,1989</a></td><td>forklaring på noe særsynt i</td><td>naturen</td><td style='text-align:left'>. Det kan være at</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009070804087' target='_'>Langhelle, Oluf,Fra ideer til politikk: Bærekraftig utvikling - svada eller rettesnor for samfunnsutviklingen,2000</a></td><td>økonomisk vekst innenfor de grenser</td><td>naturen</td><td style='text-align:left'>setter 8 . Dryzeks konklusjon</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009070804087' target='_'>Langhelle, Oluf,Fra ideer til politikk: Bærekraftig utvikling - svada eller rettesnor for samfunnsutviklingen,2000</a></td><td>å bryte med de grenser</td><td>naturen</td><td style='text-align:left'>setter for menneskelig aktivitet .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009070804087' target='_'>Langhelle, Oluf,Fra ideer til politikk: Bærekraftig utvikling - svada eller rettesnor for samfunnsutviklingen,2000</a></td><td>må skje innenfor grenser som</td><td>naturen</td><td style='text-align:left'>setter . Bærekraftig utvikling ble</td></tr>
# </table>

# %% [markdown]
# Kommandoen *get_konk()* tar parametre for å begrense søket - noen er satt opp med defaultverdier. Parametrene er en måte spesifisere et korpus på, men se nedenfor for andre måter å gjøre akkurat det på.

# %%
get_konk('naturen', {'size':10, 'corpus':'bok', 'before':12, 'after':12, 'title':'%NOU%','yearfrom':1990})
# Out:
# <table><tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010021500105' target='_'>Jorand, Vigdis Danielsen,Chouette nouvelle,1998</a></td><td>Både sjø og fjell er populære reisemål , dessuten blir « tilbake-til-</td><td>naturen</td><td style='text-align:left'>» - turer å la sykkeltur , tema-reiser og det å oppdage</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010021500105' target='_'>Jorand, Vigdis Danielsen,Chouette nouvelle,1998</a></td><td>Som 17 - åring begynte han for alvor å male ute i</td><td>naturen</td><td style='text-align:left'>, der han forsøkte å feste lysets forgjengelige effekt på lerretet .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010060303018' target='_'>Costantino, Maria,Art Nouveau,1998</a></td><td>overflaten for å søke motivets innerste kvaliteten Kunsten imiterte ikke lenger slavisk</td><td>naturen</td><td style='text-align:left'>, men søkte å avdekke virkelighetens skjulte aspekter , hvor sansene ,</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010060303018' target='_'>Costantino, Maria,Art Nouveau,1998</a></td><td>ikke skulle være imiterende eller historiske . De skulle være gjenskapelser av</td><td>naturen</td><td style='text-align:left'>, og designen skulle være tro mot de overflater de besmykket .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010060303018' target='_'>Costantino, Maria,Art Nouveau,1998</a></td><td>og var i begynnelsen delt mellom de dekorative kurvede linjeformer inspirert av</td><td>naturen</td><td style='text-align:left'>som hos Horta og Guimard , og de mer rettlinjede og abstrakte</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010060303018' target='_'>Costantino, Maria,Art Nouveau,1998</a></td><td>få arbeider som er uovertrufne i oppfinnsomhet og kreativitet . Galle så</td><td>naturen</td><td style='text-align:left'>som sin største inspirasjonskilde, og hentet derfra både form og dekorative elementer</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010060303018' target='_'>Costantino, Maria,Art Nouveau,1998</a></td><td>mot naturalismen sentrert om en avvisning av impresjonistenes vekt på troskap mot</td><td>naturen</td><td style='text-align:left'>, noe som medførte kunstnerens underordning under sitt umiddelbare synsinntrykk . I</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010060303018' target='_'>Costantino, Maria,Art Nouveau,1998</a></td><td>og fremst som en avvisning av den impresjonistiske vekt på troskap mot</td><td>naturen</td><td style='text-align:left'>. I malerier som Mystisk blomst ( 1875 ) la Gustave Moreau</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010060303018' target='_'>Costantino, Maria,Art Nouveau,1998</a></td><td>1897 forklarte Hodler at hans motiver skulle uttrykke de ytre elementer i</td><td>naturen</td><td style='text-align:left'>hvori , etter hans mening , dens essensielle skjønnhet fantes . Blant</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010060303018' target='_'>Costantino, Maria,Art Nouveau,1998</a></td><td>moter og stiler . I et forsøk på å oppnå harmoni med</td><td>naturen</td><td style='text-align:left'>og miljøet , fremmet popkulturen i 1950 - og 1960 - årene</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010060303018' target='_'>Costantino, Maria,Art Nouveau,1998</a></td><td>« sannhet mot</td><td>naturen</td><td style='text-align:left'>» . Det er derfor ikke overraskende at Art Nouveau opplevde en</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016011848103' target='_'>Sanna, Angela,Art nouveau,2010</a></td><td>detaljer , inspirert av</td><td>naturen</td><td style='text-align:left'>, eller lineære former som forente</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016011848103' target='_'>Sanna, Angela,Art nouveau,2010</a></td><td>och andra metamorfa detaljer med inspiration från</td><td>naturen</td><td style='text-align:left'>eller linjåra former som forenade funktion och elegans i en fantasifull formgivning</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016011848103' target='_'>Sanna, Angela,Art nouveau,2010</a></td><td>blomster og metamorfiske detaljer var inspireret af</td><td>naturen</td><td style='text-align:left'>eller</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016011848103' target='_'>Sanna, Angela,Art nouveau,2010</a></td><td>None</td><td>naturen</td><td style='text-align:left'>.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016011848103' target='_'>Sanna, Angela,Art nouveau,2010</a></td><td>for att tillverka metamorfa , polykroma pjåser , ofta med inspiration från</td><td>naturen</td><td style='text-align:left'>.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016011848103' target='_'>Sanna, Angela,Art nouveau,2010</a></td><td>inspireret af</td><td>naturen</td><td style='text-align:left'>.</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016011848103' target='_'>Sanna, Angela,Art nouveau,2010</a></td><td>skdnhet och funktion . Rorelsen kånnetecknas av att man anvånder motiv från</td><td>naturen</td><td style='text-align:left'>( våxter och djur ) , motiv med ursprung i japansk konst</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009112604019' target='_'>Jorand, Vigdis Danielsen,Chouette nouvelle,1997</a></td><td>om høsten som kommer , og hva det innebærer av forandringer i</td><td>naturen</td><td style='text-align:left'>. Det synges også om to som elsker hverandre og om barn</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032908102' target='_'>Fjeldstad, Walborg,Art Nouveau som inspirasjon i skapende arbeid,2004</a></td><td>, påvirket den vestlige smak . Den japanske kunsten vendte seg mot</td><td>naturen</td><td style='text-align:left'>, tok opp i seg naturens linjespill og organiske former . Gjennom</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032908102' target='_'>Fjeldstad, Walborg,Art Nouveau som inspirasjon i skapende arbeid,2004</a></td><td>ble den japanske kunsten en betydelig læremester , nå ble en bevisst</td><td>naturen</td><td style='text-align:left'>som en umettelig kilde å øse av - i stedet for etteraping</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032908102' target='_'>Fjeldstad, Walborg,Art Nouveau som inspirasjon i skapende arbeid,2004</a></td><td>Jean Jaque Rousseau ' s tanker « Tilbake til</td><td>naturen</td><td style='text-align:left'>» gjorde seg også gjeldende . Dette passet godt sammen med den</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032908102' target='_'>Fjeldstad, Walborg,Art Nouveau som inspirasjon i skapende arbeid,2004</a></td><td>keltisk , gotisk , rokokko og japansk kunst . For mange ble</td><td>naturen</td><td style='text-align:left'>forbilde i søking mot en ny stil . Stilens bløte , svungne</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032908102' target='_'>Fjeldstad, Walborg,Art Nouveau som inspirasjon i skapende arbeid,2004</a></td><td>Gjennom parolen « tilbake til</td><td>naturen</td><td style='text-align:left'>» ble kroppen gjenoppdaget . Det dreide seg selvfølgelig om kvinnekroppen .</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032908102' target='_'>Fjeldstad, Walborg,Art Nouveau som inspirasjon i skapende arbeid,2004</a></td><td>. Dette er forvridde former med ulike kurver som finnes ute i</td><td>naturen</td><td style='text-align:left'>. Formene er omhyggelig uttenkt , de er konstruksjonsmessig riktige og geometrisk</td></tr>
# <tr><td><a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011032908102' target='_'>Fjeldstad, Walborg,Art Nouveau som inspirasjo

# %% [markdown]
# ### Samme konk mot aviser  (kan ta litt tid)

# %% [markdown]
# Bøker og aviser deler litt på egenskaper. Foruten årstall vil for eksempel 'title' gjøre begrensing på boktitler for bøker, og avisnavn for aviser. Årstall begrenser utgivelsesår.

# %%
get_konk('arbeid', {'size':5, 'title':'aftenposten','corpus':'avis', 'yearfrom':1950, 'yearto':1955})
# Out:
# <table><tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19550506_96_206_1' target='_'>aftenposten-19550506</a></td><td>lJ-49 " . Efter dagens</td><td>arbeid</td><td style='text-align:left'>, gå til S og</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19550506_96_206_1' target='_'>aftenposten-19550506</a></td><td>form . still , som</td><td>arbeid</td><td style='text-align:left'>, formann på verk- sted</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19550506_96_206_1' target='_'>aftenposten-19550506</a></td><td>nelse , erfaring i sosialt</td><td>arbeid</td><td style='text-align:left'>og interesse for og innsikt</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19550506_96_206_1' target='_'>aftenposten-19550506</a></td><td>regne med å få varig</td><td>arbeid</td><td style='text-align:left'>. Lonn etler regulativet for</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19550506_96_206_1' target='_'>aftenposten-19550506</a></td><td>avdelingen . Kjennskap til lonnings-</td><td>arbeid</td><td style='text-align:left'>ønskelig . I , onn</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19520103_93_3_1' target='_'>aftenposten-19520103</a></td><td>VI har 1000 flere 1</td><td>arbeid</td><td style='text-align:left'>i ftr . Men det</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19520103_93_3_1' target='_'>aftenposten-19520103</a></td><td>At redningsmannskapet utforte et førsteklasses</td><td>arbeid</td><td style='text-align:left'>, kan det ikke være</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19520103_93_3_1' target='_'>aftenposten-19520103</a></td><td>kjærlighet for Hode Kors '</td><td>arbeid</td><td style='text-align:left'>i Norge er vel kjent</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19520103_93_3_1' target='_'>aftenposten-19520103</a></td><td>. Den skildrer det mangesidige</td><td>arbeid</td><td style='text-align:left'>ombord på skipet i storm</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19520103_93_3_1' target='_'>aftenposten-19520103</a></td><td>populære romaner — 48 timers</td><td>arbeid</td><td style='text-align:left'>, 20.000 franc firtjsneste for</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_olympiaposten_null_19520214_0_1_1' target='_'>aftenposten-19520214</a></td><td>så er det det fantastiske</td><td>arbeid</td><td style='text-align:left'>som er utført her på</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_olympiaposten_null_19520214_0_1_1' target='_'>aftenposten-19520214</a></td><td>: e skiene i sitt</td><td>arbeid</td><td style='text-align:left'>for føden . Det var</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_olympiaposten_null_19520214_0_1_1' target='_'>aftenposten-19520214</a></td><td>daglig være å finne i</td><td>arbeid</td><td style='text-align:left'>, og selve det tekniske</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_olympiaposten_null_19520214_0_1_1' target='_'>aftenposten-19520214</a></td><td>i det , vet hvilket</td><td>arbeid</td><td style='text-align:left'>som ligger bak en olympiade</td></tr>
# <tr><td><a href='https://www.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_olympiaposten_null_19520214_0_1_1' target='_'>aftenposten-19520214</a></td><td>til Italia for å søke</td><td>arbeid</td><td style='text-align:left'>. — Men hvis det</td></tr>
# </table>

# %% [markdown]
# ## Bygg et korpus av bøker
#
# Får å bygge et korpus av bøker (aviser er i kjømda) brukes kommandoen *get_urn()* med nesten de samme parametrene som for *get_konk()*.
#
# Man kan også finne URN-er i bokhylla, eller lage en liste med URN-er i en tekstfil og bruke kommandoen *urn_from_text()*. Se nedenfor.

# %% [markdown]
# #### get_urn()
#
# Kommandoen *get_urn()* gir et tilfeldig utvalg bøker innenfor spesifikasjonene.
# Aktiver cellen under et par ganger for å se effekten.

# %%
nb.get_urn({'title':"%NOU%", 'lang':'nob', 'year':1998})
# Out:
# [[2014062606117, 'Waage, Trond', '"Chez nous on se débrouille"', 2002],
#  [2013030608150,
#   '',
#   'Oppfølging av NOU 2000:16, Tobakksindustriens erstatningsansvar',
#   2002],
#  [2011032908102,
#   'Fjeldstad, Walborg',
#   'Art Nouveau som inspirasjon i skapende arbeid',
#   2004],
#  [2014031806080, '', 'Høring - NOU 2006:10', 2006],
#  [2012120505037,
#   'Bjorvatn, Afsaneh',
#   'Prophylaxis with fondaparinux versus enoxaparin against venous thromboembolism after major orthopaedic surgery',
#   2005],
#  [2010031507008, 'Jorand, Vigdis Danielsen', 'Chouette nouvelle', 1999],
#  [2011062308096, 'Garté, Tiger', 'Burnout', 2007],
#  [2010060303018, 'Costantino, Maria', 'Art Nouveau', 1998],
#  [2013103106048, '', '"The World is not enough"', 2006],
#  [2012041705005,
#   'Bjørnsrud, Halvor',
#   'Kvalitetsutvalgets NOU 2003: 16 I første rekke, med fokus på inkluderende skole, drøftet i forhold til didaktisk relasjonstenkning',
#   2004]]

# %%
nb.get_freq(2014031806080).most_common()
# Out:
# [('for', 33),
#  ('.', 32),
#  ('og', 31),
#  ('om', 21),
#  ('i', 19),
#  ('fornærmede', 19),
#  (',', 19),
#  ('til', 17),
#  ('å', 13),
#  ('av', 13),
#  ('Utvalget', 9),
#  ('skulle', 8),
#  ('foreslår', 8),
#  ('etterlatte', 8),
#  ('at', 8),
#  ('rett', 7),
#  ('også', 7),
#  ('en', 6),
#  ('det', 6),
#  ('alle', 6),
#  ('Det', 6),
#  ('utvalget', 5),
#  ('gis', 5),
#  ('fornærmedes', 5),
#  ('eller', 5),
#  ('de', 5),
#  ('burde', 5),
#  ('ved', 4),
#  ('utrede', 4),
#  ('reglene', 4),
#  ('pårørende', 4),
#  ('norske', 4),
#  ('ble', 4),
#  (')', 4),
#  ('(', 4)]

# %% [markdown]
# ### Med kriterier
#
# Vanligvis begrenses korpuset til et helt spesifikt sett av bøker. Fra bibliotekets metadata er både katalogiseringsdata og klassifikasjonsdata tilgjengelig, som forfatter, tittel og år, kjønn (gender), tema (subject) og Dewey (ddk).
#
# Her settes dataene opp på formen
#
#     navn = definisjon
#     navn
#
# Første linje definerer navnet, andre viser innholdet. Husk å endre *navn* når cellene kopieres!

# %%
nb.get_urn({'subject':'språk', 'ddk':'4%', 'year':1950, 'next':50, 'limit':30})
# Out:
# [[2008052104071, 'Voss, J. Fredrik', 'Norsk-tysk ordbok', 1969],
#  [2008102704056, 'Høgberg, Eva', 'Håndbok i grammatikk og språkbruk', 2000],
#  [2011050306031,
#   '',
#   'Studier i norsk språkvitenskap = Studies in Norwegian linguistics',
#   1981],
#  [2011062305011, 'Heggstad, Leiv', 'Fornorskingsordbok', 1958],
#  [2007072704027, '', 'Terminologien i norsk språklære', 1977],
#  [2010091608071,
#   'Gullichsen, Harald',
#   'Form, substans og språklig tegn',
#   1990],
#  [2011050506116, 'Eifring, Halvor', 'Høy eller stein?', 1985],
#  [2012121108021,
#   '',
#   'Studier i norsk språkvitenskap = Studies in Norwegian linguistics',
#   1993],
#  [2012012308184, 'Skard, Vemund', 'Norsk språkhistorie', 1972],
#  [2009102700081, 'Bull, Ella Holm', 'Åarjel-saemien', 1996],
#  [2007032801034, 'Hjort, J.B.', 'Sprogstridens kvintessens', 1963],
#  [2015090808124, 'Hvenekilde, Anne', 'Snakker du norsk?', 1986],
#  [2008060304064, 'Sandvei, Marius', 'Svensk-norsk ordbok', 1979],
#  [2015062308157, 'Fabricius-Hansen, Cathrine', 'Å lese tysk sakprosa', 1986],
#  [2012012308050, 'Rytter, Olav', 'Slavisk målreising', 1971],
#  [2009101600049, 'Haugen, Einar', 'Norsk engelsk ordbok', 1984],
#  [2012111305040,
#   '',
#   'Nynorsk litteraturantologi for den vidaregåande skolen',
#   1977],
#  [2007070401079, 'Strøm, Doris', 'Tysk-norsk teknisk ordbok', 1979],
#  [2010121320005, 'Skolt, Knut', 'Hemsedalsmålet', 1999],
#  [2016063008009, '', 'This way', 1972],
#  [2010062908094,
#   'Börestam Uhlmann, Ulla',
#   'Språkmöten och mötesspråk i Norden',
#   1991],
#  [2007090501045, 'Faarlund, Jan Terje', 'Morfologi', 1988],
#  [2007050404045, 'Bjerke, André', 'Dannet talesprog', 1966],
#  [2009102904098, '', 'Ordbog over det norrøne prosasprog', 1995],
#  [2010070808085,
#   'Graedler, Anne-Line',
#   'Morphological, semantic and functional aspects of English lexical borrowings in Norwegian',
#   1998],
#  [2007121800050, 'Manne, Gerd', 'Bo i Norge', 1994],
#  [2010071408105, 'Skjekkeland, Martin', 'norske dialektane', 1997],
#  [2013010808118, 'Guttorm, Ellen Marit', "Gåi'ke-miel'ki", 1975],
#  [2008060300064,
#   'Parneman, Helge',
#   'Differensiert tysk grammatikk for ungdomsskolen og den videregående skole',
#   1980],
#  [2016052708029, 'Vinje, Finn-Erik', 'Skriveregler', 1976]]

# %%
ordbøker = nb.get_urn({'ddk':'4%', 'year':1910, 'title':"%bokmålsord%", 'next':100, 'limit':30})
ordbøker
# Out:
# [[2013061906058, 'Gundersen, Dag', 'Gyldendals bokmålsordliste', 2007],
#  [2013081506040, '', 'Bokmålsordboka', 1993],
#  [2008061304034, '', 'Bokmålsordlista', 1992],
#  [2011103124042, '', 'Bokmålsordboka', 1986],
#  [2009070701034, '', 'Bokmålsordbok', 1991],
#  [2016072548020, '', 'Bokmålsordboka', 2004],
#  [2010111508072, '', 'Bokmålsordbok', 1991],
#  [2011060308097, 'Hjulstad, Håvard', 'Bokmålsordliste', 2006],
#  [2011062808148, '', 'Bokmålsordboka', 2005]]

# %%
nou = nb.get_urn({ 'year':1998, 'title':"%", 'ddk':"344%", 'next':100, 'limit':3000})
nou
# Out:
# [[2011061008133, 'Fougner, Jan', 'Arbeidsmiljøloven', 2006],
#  [2011071306099, '', 'Materialsamling i arbeidsrett', 2004],
#  [2013071008111, 'Gottschalk, Petter', 'Hvitsnippadvokatene', 2013],
#  [2015051108154, '', 'Privatskolelova og forskrifter', 2010],
#  [2011100406107,
#   'Kjøren, Anders',
#   'Virksomheters plikter til å ha og formidle miljøinformasjon etter miljøinformasjonsloven',
#   2004],
#  [2011102608072, 'Skaug, Lasse', 'Jus i eldreomsorgen', 2004],
#  [2013071608229, '', 'Opplæringslova og forskrifter', 2012],
#  [2014072308058, 'Jakhelln, Henning', 'Oversikt over arbeidsretten', 2006],
#  [2011030905009, '', 'Barna under lovens vinger?', 2000],
#  [2011051808060, 'Storeng, Nils H.', 'Arbeidslivets spilleregler', 2006],
#  [2010081108003,
#   'Rivertz, Johan Sverre',
#   'Barns rett til godt inneklima i barnehager og skoler',
#   1999],
#  [2016070608042,
#   '',
#   'Helsepersonelloven og pasientrettighetsloven med nye forskrifter',
#   2002],
#  [2013010706064, '', 'Innføring i byggereglene', 2011],
#  [2014031106049, 'Storeng, Nils H.', 'Arbeidslivets spilleregler', 2011],
#  [2011033108046, 'Ertzaas, Ulf', 'Arbeidsrettslig håndbok', 2004],
#  [2015070608016, 'Dege, Jan Tormod', 'individuelle arbeidsrett', 2009],
#  [2013120205104, '', 'Kommunehelsetjenesteloven, sosialtjenesteloven', 2006],
#  [2012060806028, 'Stabursvik, Eva', 'Hvit front', 2005],
#  [2008090300111,
#   'Bautz, Dag Vidar',
#   'Tilsattes rettigheter ved sykdom, fødsel, adopsjon m.m',
#   1998],
#  [2013071808190, '', 'Pensjonslovene og folketrygdreformen III', 2013],
#  [2013010208109,
#   '',
#   'Helsepersonelloven og pasient- og brukerrettighetsloven',
#   2012],
#  [2009021200098, 'Storeng, Nils H.', 'Arbeidslivets spilleregler', 2003],
#  [2012121705095, 'Stette, Øystein', 'Skolejus', 2005],
#  [2013010208110, '', 'Psykisk helsevernloven med forskrifter', 2012],
#  [2009021200080, '', 'Omstilling og nedbemanning', 2003],
#  [2008120300082,
#   'Trøim, Isa',
#   'Arkeologisk forskning og det lovregulerte fornminnevernet',
#   1999],
#  [2013081406050, '', 'Spesialundervisning', 2009],
#  [2015111308109, 'Pedersen, Randi', 'bok om egen rettssak', 2000],
#  [2014061708008, 'Øie, Ole-Erik', 'Trygderetten og dens prosessordning', 2010],
#  [2009041704017, '', 'Helsepersonelloven og pasientrettighetsloven', 2000],
#  [2013062808063,
#   '',
#   'Lov om arbeidsmiljø, arbeidstid og stillingsvern mv. (Arbeidsmiljøloven)',
#   2013],
#  [2014072308083, 'Molven, Olav', 'Helse og jus', 2009],
#  [2011102506063, 'Kjønstad, Asbjørn', 'Velferdsrett I', 2005],
#  [2015072308352, '', 'Voksenopplæringsloven og forskrifter', 2011],
#  [2011042708095, '', 'Aktuelle lover for helsetjenesten', 2002],
#  [2011051808064, '', 'Barnevern 2005-2007', 2005],
#  [2010081808088,
#   'Wettestad, Jørgen',
#   'Designing effective environmental regimes',
#   1999],
#  [2011071406077, 'Simonsen, Sigmund', 'Helseforskningsrett', 2005],
#  [2009021600030, '', 'Velferdsrett III', 2002],
#  [2011071408070, 'Stang, Elisabeth Gording', 'Det er barnets sak', 2007],
#  [2014092209011,
#   '',
#   'Lovsamling for styrere og pedagogiske ledere i barnehagen',
#   2009],
#  [2015060808059,
#   'Søvig, Karl Harald',
#   'Tvang overfor rusmiddelavhengige',
#   2007],
#  [2011102408170, 'Eikrem, Tove', 'Jungelhåndboka 2004', 2004],
#  [2011032208017, 'Larsen, Guri', 'Barnevern i hundre år', 2002],
#  [2010050408013, 'Engelsrud, Gerd', 'Styring og vern', 1999],
#  [2011052008156, 'Jakhelln, Henning', 'Arbeidsmiljøloven 2005', 2006],
#  [2010080508054,
#   'Warberg, Lasse A.',
#   'Barn og unges rettigheter som pasienter',
#   1998],
#  [2011061708036, '', 'Bagadus bargobiraslága ja luopmolága birra', 2007],
#  [2014072206120,
#   'Brucker, Ingrid Fladberg',
#   'Særlig uavhengig stilling',
#   2009],
#  [2013120606055, 'Allstrin, Tor', 'Endring og opphør av arbeidsforhold', 2008],
#  [2010092106016,
#   '',
#   'Veileder til forskrift om miljørettet helsevern i barnehager og skoler m.v',
#   1998],
#  [2015041008033,
#   'Pedersen, Randi',
#   'Informasjon og kulturarv vis-à-vis sensur i det 21. århundre',
#   2000],
#  [2015072308304, 'Kjønstad, Asbjørn', 'Helserett', 2007],
#  [2014071508131, '', 'Pasientrettighetsloven', 2009],
#  [2008101704020, '', 'Medisinske feil', 2000],
#  [2013070106047, '', 'Barnevernloven', 2004],
#  [2011090606152, 'Kjellevold, Alice', 'Retten til individuell plan', 2005],
#  [2013071508268,
#   'Eriksen, Bjørn',
#   'Saksbehandlingsregler ved oppsigelse og avskjed',
#   2011],
#  [2013010208111,
#   '',
#   'Spesialisthelsetjenesteloven og helseforetaksloven med forskrifter og vedtekter',
#   2012],
#  [2008082704030, '', 'Velferdsrett II', 1999],
#  [2011062308175, '', 'Arbeidsrett', 2007],
#  [2011102605072, '', 'God forskning - bedre helse', 2005],
#  [2015071608039, 'Aune, Helga', 'Deltidsarbeid', 2009],
#  [2014070206112,
#   '',
#   'Lov av 2. juli 1999 nr. 62 om etablering og gjennomføring av psykisk helsevern (psykisk helsevernloven)',
#   2003],
#  [2014111808079, 'Martinsen, Eldbjørg Håkonsen', 'IPPC-direktivet', 2008],
#  [2015042108198,
#   '',
#   'Spesialisthelsetjenesteloven og helseforetaksloven med nye forskrifter og vedtekter',
#   2002],
#  [2013111808081, '', 'Juss § eiendom', 2002],
#  [2015102008010, 'Syse, Aslak', 'Pasientskaderett', 2011],
#  [2008090800064, 'Raugland, Vidar', 'Skolejuss', 1999],
#  [2015110407554,
#   '',
#   'Ferieloven av 29. april 1988 nr 21 med kommentarer',
#   2001],
#  [2008111204051, 'Ohnstad, Bente', 'Juss for helse- og sosialarbeidere', 2001],
#  [2013061706065,
#   '',
#   'Psykisk helsevernloven med innledning og kommentarer',
#   2002],
#  [2011071106088, '', 'Helsepersonelloven og pasientrettighetsloven', 2004],
#  [2008111204019, 'Larsen, Per Arne', 'Arbeidsmiljøloven', 2001],
#  [2009062201050, '', 'Velferdsrett II', 2003],
#  [2013062005061,
#   'Pettersen, Karen-Sofie',
#   'Kommunale oppreisningsordninger for tidligere barnevernsbarn',
#   2010],
#  [2011090108040, 'Ulseth, Terese Smith', 'Daglig leders stillingsvern', 2006],
#  [2016022308237, '', 'Lovsamling for Den norske kirke', 2013],
#  [2013102106009, '', 'Lovsamling for Den norske kirke', 2010],
#  [2012101205002, 'Myhrer, Tor-Geir', 'Som siste utvei', 2005],
#  [2014103138021, '', 'Smittevernloven', 2002],
#  [2014052608208,
#   'Østberg, Bjørn Ivar Christie',
#   'Telekirurgi i et rettslig perspektiv',
#   2008],
#  [2011072108007,
#   'Resare, Karianne Karlsen',
#   'Barnehageloven 17. juni 2005 nr. 64',
#   2006],
#  [2016042108105, '', 'Rett om bord', 2012],
#  [2009020404010,
#   '',
#   'Bedre kommunal og regional planlegging etter plan- og bygningsloven',
#   2001],
#  [2016021608206,
#   'Schütz, Sigrid Eskeland',
#   'Miljøkonsekvensutgreiing av planar og tiltak',
#   2007],
#  [2011102408141, 'Lindboe, Knut', 'Barnevernrett', 2008],
#  [2011032508194,
#   '',
#   'Aktuelle lover og forskrifter for foreldre med barn i grunnskolen',
#   2004],
#  [2012052905113,
#   '',
#   'Lov om arbeidsmiljø, arbeidstid, stillingsvern mv. (Arbeidsmiljøloven)',
#   2006],
#  [2008112704068, '', 'Pleie- og omsorgstjenesten 2002', 2001],
#  [2013070938044, 'Grongstad, Lars', 'Juss i skolehverdagen', 2009],
#  [2016062408068, '', 'Artikkelsamling i arbeidsrett', 2001],
#  [2008112004066, '', 'Pasientrettighetsloven', 2001],
#  [2014031805060, '', 'Diskriminerings- og likestillingsrett', 2008],
#  [2011092708081, '', 'Folketrygdloven 28. februar 1997 nr. 19', 2006],
#  [2014032806016,
#   '',
#   'Veiledning til forskrift om tekniske krav til byggverk (TEK10)',
#   2011],
#  [2011061708052,
#   'Nåmdal, Endre',
#   'Ansvarsgjennombrot som grunnlag for aksjonæransvar for miljøskadar',
#   2008],
#  [2011091906010, '', 'Pasientrettighetsloven', 2004],
#  [2011091908130, 'Benson, Thomas', 'Arbeidsrettsboka', 2008],
#  [2012121108015, '', 'Når døden tjener livet', 2011],
#  [2009052804026, 'Lindboe, Knut', 'Barnevernrett', 2003],
#  [2008110600075, '', 'Opplæringslova med forskrifter', 2001],
#  [2014071608024, '', 'Lovsamling for Den norske kirke', 2000],
#  [2008091504017,
#   'Halvorsen, Marit',
#   'Rettslige grunnlag for medisinsk behandling',
#   1998],
#  [2011081905011, '', 'Forurensningsloven', 2005],
#  [2008080504095, 'Friberg, Odd', 'Arbeidsmiljøloven', 1998],
#  [2013111908016, '', 'Smittevernloven', 2001],
#  [2011032508083, '', 'Elevenes fysiske og psykososiale skolemiljø', 2003],
#  [2013040208014, '', 'Lov om arbeidervern og arbeidsmiljø', 2001],
#  [2011053108036,
#   'Wergeland, Ebba',
#   'Arbeidsmiljøloven, sykefraværet og sekstimersdagen',
#   2006],
#  [2009041504090,
#   '',
#   'Forsikringsselskapers innhenting, bruk og lagring av helseopplysninger',
#   2000],
#  [2013121006092,
#   'Lundeberg, Ingrid Rindal',
#   'De urettmessige mindreverdige',
#   2008],
#  [2011100406019, 'Kjellevold, Alice', 'Sosialhjelp på vilkår', 2004],
#  [2009021904034, 'Molven, Olav', 'Sykepleie og jus', 2003],
#  [2010032405050, '', 'Kulturmuitoláhka', 1998],
#  [2013080838117, '', 'Helsepersonelloven', 2010],
#  [2013071608163,
#   '',
#   'Taushetsplikt, opplysningsrett og opplysningsplikt',
#   2013],
#  [2011060906078,
#   'Aasen, Henriette Sinding',
#   'Pasientens rett til selvbestemmelse ved medisinsk behandling',
#   2000],
#  [2008120900016, '', 'Norske pengespel i ei digital framtid', 2001],
#  [2013040408029, 'Kjønstad, Asbjørn', 'Velferdsrett I', 2008],
#  [2009012304077, 'Molven, Olav', 'Helse og jus', 2002],
#  [2013042306160,
#   '',
#   'Lov om arbeidsmiljø, arbeidstid og stillingsvern mv. (Arbeidsmiljøloven)',
#   2007],
#  [2013071608230, '', 'Opplæringslova og forskrifter', 2012],
#  [2011041408079, '', 'Folketrygdloven 28. februar 1997 nr 19', 2003],
#  [2010080508064, 'Warberg, Lasse A.', 'Juss og smittevern', 1998],
#  [2010090208041, '', 'Fangehåndboka 1998', 1998],
#  [2011091906083, '', 'Mer effektiv bygningslovgivning II', 2005],
#  [2014032706118, 'Eikrem, Tove', 'Jungelhåndboka 2008', 2008],
#  [2009012204078, 'Kjellevold, Alice', 'Retten til individuell plan', 2002],
#  [2010081803014,
#   '',
#   'Aktuelle lover og forskrifter m.m. for foreldre med barn i grunnskolen',
#   1999],
#  [2009072704139, '', 'arbeidsliv for trygghet, inkludering og vekst', 2004],
#  [2008090300084,
#   'Tyrén, Carl Wilhelm',
#   'Håndbok i plan- og bygningsloven med forskrifter',
#   1998],
#  [2011052408033,
#   'Oppedal, Mons',
#   'Barns rettssikkerhet ved plassering i fosterhjem eller institusjon etter barnevernloven',
#   2005],
#  [2008082500008, 'Holgersen, Gudrun', 'Trygderettslige emner', 1998],
#  [2015072908298,
#   'Flatseth, Merethe',
#   'Førende forestillinger i fosterpolitikken',
#   2009],
#  [2015021106120, 'Jakhelln, Henning', 'Arbeidsrettslige studier', 2000],
#  [2015090106166, 'Steen, Sven Iver', 'Obligatorisk tjenestepensjon', 2006],
#  [2013011606043, '', 'Helsepersonelloven og pasientrettighetsloven', 2007],
#  [2008082200007, '', 'Folketrygdloven med kommentarer', 1998],
#  [2014091708108, 'Lowzow, Andreas Hjelseth', 'Ny alderspensjon', 2010],
#  [2012110108021, 'Eilertsen, Bjørnar', 'Juss for sykepleiere', 2009],
#  [2010072308048,
#   'Warberg, Lasse A.',
#   'Rettsregler om kvinner som pasienter',
#   1998],
#  [2009030200088, '', 'Doms- og materialsamling i velferdsrett', 1998],
#  [2012082908106,
#   '',
#   'Vurdering av behandlingsvilkåret i psykisk helsevernloven',
#   2009],
#  [2013070108202, '', 'Orientering om medvirkning og vernetjenesten', 2013],
#  [2014120108238,
#   'Lindemark, Solveig Ingeløv',
#   'Rikspolitiske retningslinjer',
#   1999],
#  [2013102806091, '', 'Standardisert personskadeerstatning', 2011],
#  [2011041408100, '', 'Aktuelle lover for helse- og sosialsektoren', 2000],
#  [2009042000053, '', 'Lovsamling for Den norske kirke', 1998],
#  [2011022208009,
#   'Hjorthaug, Torbjørn Backer',
#   'Frede Castbergs statskirkeoppfatning',
#   1998],
#  [2015101648055,
#   'Berge, Anna Ragnhild Brattebråten',
#   'Rettighetshåndboka',
#   2004],
#  [2016031548111, '', 'Velferd og rettferd', 2013],
#  [2008120904103,
#   'Bjørnstad, Gry',
#   'Helsepersonelloven, pasientrettighetsloven',
#   2001],
#  [2014040706200, '', 'Økt selvbestemmelse og rettssikkerhet', 2011],
#  [2014022408133,
#   '',
#   'Forskrift om krav til byggverk og produkter til byggverk',
#   2007],
#  [2011070108163, 'Eikrem, Tove', 'Funksjonshemmedes rettigheter', 2003],
#  [2013082908077, 'Eikrem, Tove', 'Jungelhåndboka 2009', 2009],
#  [2011032406040, '', 'På jobb i utlandet', 2001],
#  [2008112404006,
#   'Due-Tønnessen, Lars',
#   'Løslatelse etter halv soningstid',
#   2001],
#  [2012121206158, 'Engelsrud, Gerd', 'Oppgaver i arbeidsrett', 2010],
#  [2014061806150, 'Warberg, Lasse A.', 'Norsk helserett', 2011],
#  [2014110407698, 'Hansen, Rune Bård', 'Arbeidsmiljøkriminalitet', 2010],
#  [2008090804052, 'Schiøtz, Aina', 'Museumslov - trenger vi det?', 1999],
#  [2011062408104, 'Oppedal, Mons', 'Akutthjemlene i barnevernloven', 2008],
#  [2014031006110, '', 'Omstilling og nedbemanning', 2011],
#  [2010090203032,
#   'Warberg, Lasse A.',
#   'Rettsregler om pasienters pårørende',
#   1998],
#  [2013112707005, '', 'Helse, miljø og individ 1998', 1998],
#  [2008100800003, '', 'Lov om arbeidervern og arbeidsmiljø', 2000],
#  [2013061006002, 'Eilertsen, Bjørnar', 'Juss for helsesøstre', 2009],
#  [2009021604138, 'Storeng, Nils H.', 'Arbeidslivets spilleregler', 2003],
#  [2009021704006, '', 'Sosialrett', 2003],
#  [2013031106154, '', 'Lovsamling for tannhelsetjenesten', 2008],
#  [2010080513008,
#   'Warberg, Lasse A.',
#   'Rettsregler om naturmedisin/alternativ medisin',
#   1998],
#  [2009032400051, 'Aarnes, Arne', '"Tilfredsstillende utbytte"', 1999],
#  [2012070306058, '', 'Universitets- og høyskoleloven av 2005', 2006],
#  [2009030304125, '', 'Det psykiske helsevern', 1998],
#  [2013031105091, '', 'Opplæringslova og forskrifter', 2008],
#  [2010031606085,
#   '',
#   'Láhkaásahus visttiid ja huksengálvvuid gáibádusaid birra',
#   1998],
#  [2016072008145, '', 'Psykisk helsevernloven med forskrifter', 2004],
#  [2014061708106, 'Hauge, Mette Sollihagen', 'Legemidler og juss', 2007],
#  [2009122200058,
#   '',
#   'Festskrift til Det juridiske fakultet ved Universitetet i Bergen i anledning 25 års jubileet',
#   2005],
#  [2011051808023, '', 'Arbeidsrett.no', 2005],
#  [2014040406030, '', 'Pensjonslovene og folketrygdreformen I', 2010],
#  [2008082200014,
#   '',
#   'Krav om forsvarlig virksomhet i tannhelsetjenesten',
#   1998],
#  [2011100308158,
#   '',
#   'Ferieloven av 29. april 1988 nr. 21 med kommentarer',
#   2006],
#  [2013070938047, 'Lilleholt, Kåre', 'Avtale om ny bustad', 2001],
#  [2011090108204, 'Lindboe, Knut', 'Barnevernloven', 2006],
#  [2016012006003,
#   'Edvardsen, Åsmund',
#   'Betaling for beboere i institusjon',
#   2011],
#  [2013102308021,
#   '',
#   'Veiledning til teknisk forskrift til Plan- og bygningsloven 1997',
#   2007],
#  [2013102806106, '', 'Fripoliser og kapitalkrav', 2012],
#  [2015071608041, '', 'Lovsamling for Den norske kirke', 2007],
#  [2009021800076,
#   'Ohnstad, Bente',
#   'Taushetsplikt, personvern og informasjonssikkerhet i helse- og sosialsektoren',
#   2003],
#  [2009042704068,
#   'Bautz, Dag Vidar',
#   'Tilsattes rettigheter ved sykdom, fødsel, adopsjon m.m',
#   1998],
#  [2011091908086,
#   'Collin-Hansen, Ragnhild',
#   'Barnets rett til opplæring og til vern mot marginalisering i skolen',
#   2008],
#  [2015061808141, '', 'Psykisk helsevernloven med forskrifter', 2008],
#  [2009030604071, '', 'Lover om alkohol i Norge', 1998],
#  [2015102308091,
#   'Aulstad, Johan Greger',
#   'Avtaler om utslipp av klimagasser',
#   2001],
#  [2011082408011, '', 'Aktuelle lover for helsetjenesten', 2007],
#  [2011090608129, '', 'Folketrygdloven', 2007],
#  [2011091506095,
#   'Øhrn, Hege Ingvoldstad',
#   'Rettigheter og plikter ved sykdom, svangerskap, fødsel og adopsjon',
#   2005],
#  [2013102406077, 'Haugli, Trude', 'Samvær i barnevernsaker', 2010],
#  [2012112308021, 'Oftebro, Ole André', 'Avtaler om kosmetisk kirurgi', 2012],
#  [2008112404034, 'Fanebust, Arne', 'Oppsigelse i arbeidsforhold', 2001],
#  [2011070705136, '', 'Velferdsrett III', 2004],
#  [2011052608130, '', 'Barnevernet og barnevernloven', 2005],
#  [2009030904050, '', 'Lov om arbeidervern og arbeidsmiljø', 1998],
#  [2014050705056,
#   'Johansen, Atle S.',
#   'Sentrale dommer til arbeidsmiljøloven',
#   2009],
#  [2009021104109, 'Nordby, Kjersti', 'Fleksibilitet til strikken ryker', 2000],
#  [2008091504088,
#   'Engh, Einar',
#   'Kan en arbeidstaker reservere seg mot at arbeidsforholdet overføres til ny arbeidsgiver?',
#   1998],
#  [2008102800094, 'Haugli, Trude', 'Samværsrett i barnevernssaker', 2000],
#  [2014063008084, '', 'Helsepersonelloven og pasientrettighetsloven', 2006],
#  [2013060406090, '', 'Opplæringslova med forskrifter', 2007],
#  [2011053008052, '', 'Arbeidsmiljøloven før og nå', 2005],
#  [2012091238010,
#   'Kvello, Viva Mørk',
#   'Store norske Spitsbergen kulkompani aktieselskap',
#   2007],
#  [2011061008112, 'Storeng, Nils H.', 'Arbeidsrett', 2006],
#  [2015020408020, 'Jakhelln, Henning', 'Oversikt over arbeidsretten', 2004],
#  [2014051208046,
#   '',
#   'Lov av 4. februar 1977 nr 4 om arbeidervern og arbeidsmiljø m.v. (arbeidsmiljøloven)',
#   1999],
#  [2011032406044, 'Skaug, Lasse', 'Asta og hennes rettigheter', 2001],
#  [2015102208283, '', 'Kommunehelsetjenesteloven ; Sosialtjenesteloven', 2008],
#  [2013081906011, 'Eikrem, Tove', 'Jungelhåndboka 2006', 2006],
#  [2013120308112, 'Aamodt, Øistein', 'Retten til hjemmeundervisning', 2001],
#  [2011032206035,
#   '',
#   'Psykisk helsevernloven og spesialisthelsetjenesteloven med nye forskrifter',
#   2001],
#  [2010051008024, 'Gjems-Onstad, Ole', 'Arbeidsrett', 1999],
#  [2013082108020, 'Molven, Olav', 'Sykepleie og jus', 2012],
#  [2014112106025, 'Kahn, Michael', 'Lærebok i kulturminnerett', 2007],
#  [2015042408152,
#   '',
#   'Forskrifter om helse, miljø og sikkerhet i petroleumsvirksomheten',
#   2001],
#  [2011082906023, '', 'Opplæringslova med forskrifter', 2005],
#  [2011031408076,
#   '',
#   'Aktuelle lover og forskrifter m.m. for foreldre med barn i grunnskolen',
#   2003],
#  [2014042308024, '', 'Opplæringslova og forskrifter', 2012],
#  [2011042708099, '', 'Aktuelle lover for helsetjenesten', 2001],
#  [2012062608162, 'Eikrem, Tove', 'Jungelhåndboka 2010', 2010],
#  [2012070306036, '', 'NS 8405', 2006],
#  [2011042708043, 'Hauge, Ragnar', 'Alkoholloven', 2000],
#  [2015060508102, '', 'Ny lov om måling', 2004],
#  [2011070505074, 'Kjønstad, Asbjørn', 'Kompendium i helserett', 2003],
#  [2009021604140, 'Storeng, Nils H.', 'Arbeidslivets spilleregler', 2003],
#  [2014071106001, '', 'Plan- og bygningsrett', 2011],
#  [2008120800049, 'Kjønstad, Asbjørn', 'Velferdsrett I', 2001],
#  [2011062405049,
#   '',
#   'Lov av 2. juli 1999 nr 64 om helsepersonell m.v. (helsepersonelloven)',
#   2003],
#  [2014050806131, 'Eidsvaag, Tine', 'Handlaus gjæte', 2008],
#  [2014062606007, 'Jakobsen, Guttorm', 'Vann- og avløpsrett', 2010],
#  [2013120608211, 'Tyrén, Carl Wilhelm', 'Plan- og bygningsloven', 2010],
#  [2008092504064, 'Storeng, Nils H.', 'Arbeidsrett', 1999],
#  [2011040806116, '', 'Helsepersonelloven', 2001],
#  [2011091608101,
#   'Bendiksen, Lena R.L.',
#   'Fratakelse av foreldreansvar og adopsjon som barnevernstiltak',
#   2007],
#  [2012103006094, 'Eilertsen, Bjørnar', 'Juss for jordmødre', 2009],
#  [2015052808117, 'Pedersen, Åge', 'Skolen som forvaltningsorgan', 2006],
#  [2011072108063, '', 'Barnehageloven 2006', 2006],
#  [2009042704064, 'Stette, Øystein', 'Skolejus 2000', 2000],
#  [2011062706056, 'Auglend, Ragnar L.', 'Politirett', 2004],
#  [2015020209087, '', 'Lovsamling for skoleledere', 2010],
#  [2013080838157, 'Kjønstad, Asbjørn', 'Innføring i trygderett', 2009],
#  [2013062606026,
#   'Østenstad, Bjørn Henning',
#   'Heimelsspørsmål i behandling og omsorg overfor psykisk utviklingshemma og aldersdemente',
#   2009],
#  [2011052008100, 'Granden, Gro', 'Ansatt, oppsagt, avskjediget?', 2006],
#  [2009031700033,
#   'Flaaterud, Stian',
#   'Bruk av tvang overfor gravide rusmiddelmisbrukere',
#   2000],
#  [2009011404149, '', 'Skolejus', 2002],
#  [2008081500049, '', 'Krav til forsvarlig virksomhet i sykehus', 1998],
#  [2013101406064, 'Marthinussen, Karl', 'NS 8406', 2007],
#  [2015072708068,
#   '',
#   'Sosial trygghet og rettssikkerhet under sosialtjenesteloven og barnevernloven',
#   2000],
#  [2012021605037, 'Cabot, Sigrid Anderssen', 'Miljøinformasjonslova', 2005],
#  [2015102208373, '', 'Psykisk helsevernloven med forskrifter', 2010],
#  [2013072208268, '', 'Plan- og bygningsloven', 2010],
#  [2012121106099, '', 'Lov om arbeidervern og arbeidsmiljø', 1999],
#  [2010120820034, 'Tengesdal, Paul', 'eventyr fra virkeligheten', 1999],
#  [2015090906163, '', 'Velferdsrett II', 2008],
#  [2014060506073,
#   '',
#   'Folkehelseloven og helse- og omsorgstjenesteloven med departementets merknader',
#   2011],
#  [2012020206019, '', 'Pleie- og omsorgstjenesten 2005', 2005],
#  [2008081500092,
#   '',
#   'Lov om grunnskolen og den vidaregåande opplæringa',
#   1998],
#  [2013071008063, '', 'Privatskolelova og forskrifter', 2012],
#  [2013070938109, 'Eriksen, Bjørn', 'Rektors styringsrett', 2012],
#  [2011072008104, '', 'Barnehageloven 2006', 2006],
#  [2011071405547, '', 'Kollektiv arbeidsrett', 2004],
#  [2009032400043,
#   'Backer, Inge Lorange',
#   'Innføring i naturressurs- og miljørett',
#   1999],
#  [2014102106037, 'Engelsrud, Gerd', 'Styring og vern', 2009],
#  [2009012904138, 'Fanebust, Arne', 'Innføring i arbeidsrett', 2002],
#  [2013042306177, 'Bugge, Hans Chr.', 'Lærebok i miljøforvaltningsrett', 2006],
#  [2014071106045, 'Ottesen, Gunnar', 'Yrkes- og arbeidslovgivning', 2010],
#  [2011033008088,
#   'Kroken, Nina',
#   'Arbeidstakers rett til å stå i stilling ved urettmessig avskjed',
#   2004],
#  [2012052906084, 'Gullbrå, Torstein', 'Dømt til behandling', 2005],
#  [2009021204111, 'Bugge, Hans Chr.', 'Forurensningsansvaret', 1999],
#  [2011031505044, '', 'Forvaltning og drift', 2001],
#  [2016011907513, '', 'Permitteringer', 1998],
#  [2008120900041,
#   '',
#   'Helsepersonelloven og pasientrettighetsloven med nye forskrifter',
#   2001],
#  [2009031904020, '', 'Opplæringslova og forskrifter', 2003],
#  [2013080508169, 'Lindboe, Knut', 'Barnevernrett', 2012],
#  [2014050805041, '', 'nlegging, vern og utbygging', 2011],
#  [2010081608080, 'Børresen, Knut Vidar', 'Byggsafe', 1999],
#  [2011080106010, 'Skårberg, Lars Olav', 'Yrkesskade', 2003],
#  [2009061600035,
#   'Pedersen, Harald',
#   'Arbeidsmiljøloven §12 og psykososialt arbeidsmiljø',
#   2002],
#  [2014061708046, '', 'Lov om alternativ behandling', 2005],
#  [2009021900094, 'Fougner, Jan', 'Arbeidsmiljøloven', 2003],
#  [2010042207049,
#   'Johansen, Thor-Erik',
#   'Inngåelse og avslutning av arbeidsforhold',
#   1999],
#  [2009041400083,
#   'Backer, Inge Lorange',
#   'Innføring i naturressurs- og miljørett',
#   2002],
#  [2016031548068, '', 'Planlegging, vern og utbygging', 2012],
#  [2016033008167, '', 'Jus på arbeidsplassen', 2001],
#  [2011040406028,
#   '',
#   'Kulturminner og kulturmiljøer, plan- og bygningsloven',
#   2001],
#  [2009022600074, 'Haave, Per', 'Sterilisering av tatere 1934-1977', 2000],
#  [2014021906312, 'Stenevik, Inger Helen', 'Dyrevelferdsloven', 2011],
#  [2013050306051, 'Tyrén, Carl Wilhelm', 'Plan- og bygningsloven', 2003],
#  [2009021600066, 'Andenæs, Kristian', 'Juss for sykepleiere', 2003],
#  [2011092208034,
#   'Bendiksen, Lena R.L.',
#   'Barn i langvarige fosterhjemsplasseringer',
#   2008],
#  [2009021200068, '', 'Trygdeytelser i Europa', 1999],
#  [2013071008056, 'Kjønstad, Asbjørn', 'Taushetsplikt om barn', 2009],
#  [2008103000062, '', 'Utkast til ny lov om brann- og eksplosjonsvern', 1999],
#  [2008090104037, '', 'Klage og klagebehandling i grunnskolen', 1999],
#  [2014062307213, '', 'Kulturminnevern', 2005],
#  [2009051304048, 'Bjørnaraa, Torgeir', 'Norsk tjenestemannsrett', 2000],
#  [2010070708163,
#   'Gjesvik, Kalle',
#   'ABC kunnskapsprøven om alkoholloven for styrere og stedfortredere',
#   1999],
#  [2011070606136,
#   'Ohnstad, Bente',
#   'Rettigheter og plikter etter ny helselovgivning',
#   2002],
#  [2010090203035, 'Warberg, Lasse A.', 'Rettsregler i eldreomsorgen', 1998],
#  [2011121408064,
#   'Befring, Anne Kjersti',
#   'Jus for hjelpepleiere og omsorgsarbeidere',
#   2004],
#  [2012111208130, 'Eikrem, Tove', 'Jungelhåndboka 2007', 2007],
#  [2011040708145, 'Storeng, Nils H.', 'Arbeidsrett', 2002],
#  [2010051208046,
#   'Johansen, Thor-Erik',
#   'Stillingsvernet i arbeidsmiljøloven',
#   1999],
#  [2009030904066,
#   'Hauge, Ragnar',
#   'Norsk alkohollovgivning gjennom 1000 år',
#   1998],
#  [2013073008028, '', 'Helse- og omsorgstjenesteloven', 2013],
#  [2008090104105, 'Gjone, Tor Aa.', 'Bedriftens personalhåndbok', 1998],
#  [2009041400071,
#   'Johansen, Thor-Erik',
#   'Inngåelse og avslutning av arbeidsforhold',
#   1998],
#  [2013041806033, '', 'Barnehageloven og forskrifter', 2009],
#  [2011031505048, 'Kjønstad, Asbjørn', 'Taushetsplikt om barn', 2001],
#  [2016021608270,
#   'Strand, Vibeke Blaker',
#   'Diskrimineringsvern og religionsutøvelse',
#   2012],
#  [2011060108083,
#   'Jacobsen, Jørn R.T.',
#   'Dom på overføring til tvungent psykisk helsevern',
#   2004],
#  [2009021900015,
#   'Sandberg, Kirsten',
#   'Tilbakeføring av barn etter omsorgsovertakelse',
#   2003],
#  [2008102800035, 'Molven, Olav', 'Helse og jus', 2000],
#  [2014072406051, 'Bugge, Hans Chr.', 'Lærebok i miljøforvaltningsrett', 2011],
#  [2011083006016, 'Ohnstad, Bente', 'Juss for helse- og sosialarbeidere', 2004],
#  [2013013106322, 'Halvorsen, Marit', 'Norsk biobankrett', 2006],
#  [2013080208064, 'Johansen, Thor-Erik', 'Kollektiv arbeidsrett', 2001],
#  [2013071708071, 'Aune, Helga', 'Deltidsarbeid', 2013],
#  [2013082905069,
#   '',
#   'Spesialisthelsetjenesteloven og helseforetaksloven med forskrifter og vedtekter',
#   2004],
#  [2010012004092, '', 'Godkjenningskatalogen', 1999],
#  [2013013008234, 'Helgeland, Geir', 'Opplæringslova', 2006],
#  [2013060405074,
#   '',
#   'Samling av lover, forskrifter m.m. i etablering og ledelse til mesterprøven',
#   2010],
#  [2014082108096,
#   'Befring, Anne Kjersti',
#   'Helsepersonelloven 2. juli 1999 nr. 64',
#   2006],
#  [2016072608001, '', 'Lovsamling for Den norske kirke', 2005],
#  [2011061405039,
#   '',
#   'Lov om etablering og gjennomføring av psykisk helsevern',
#   2001],
#  [2011040708118, 'Storeng, Nils H.', 'Arbeidsrett', 2004],
#  [2013102406000, 'Bugge, Hans Chr.', 'Lærebok i miljøforvaltningsrett', 2009],
#  [2010041603077, '', 'Avgjørelser i byggesaker 1990-1997', 1998],
#  [2014121108076, '', 'Opplæringslova og forskrifter', 2011],
#  [2014091809001, '', 'Lovsamling for skoleledere', 2008],
#  [2015091006049, '', 'Opplæringslova og forskrifter', 2010],
#  [2013073006057, '', 'Grad av utnytting', 2007],
#  [2015090706175, '', 'Forvaltning og drift', 2009],
#  [2016060608181, 'Engelsrud, Gerd', 'Styring og vern', 2013],
#  [2011051808041, '', 'Arbeidsrett.no', 2006],
#  [2013010308226,
#   'Kaspersen, Martine Refsland',
#   'Forordning (EF) nr. 883/2004 om koordinering av trygdeordninger',
#   2010],
#  [2014111407552, 'Høines, Jan Henrik', 'Retten til å trives på skolen', 2011],
#  [2009021704004, 'Engelsrud, Gerd', 'Styring og vern', 2003],
#  [2015012609010, '', 'Lovsamling for helsepersonell', 2009],
#  [2015121008051,
#   'Aasen, Henriette Sinding',
#   'Pasientens rett til selvbestemmelse ved medisinsk behandling',
#   1998],
#  [2008121604072, 'Lunde, Tom Erik', 'Permittering', 1998],
#  [2013082605072, 'Molven, Olav', 'Sykepleie og jus', 2006],
#  [2013022206077,
#   '',
#   'Lov om arbeidsmiljø, arbeidstid og stillingsvern mv',
#   2009],
#  [2014021906402, '', 'Veiledning om arbeidsmiljø i helseinstitusjoner', 2006],
#  [2009021900063, '', 'Skjerpet vern mot diskriminering i arbeidslivet', 2003],
#  [2008090100043, '', 'Næringsmiddelforskrifter', 1999],
#  [2009063001124, '', 'Rettsliggjøring av privat omsorg', 2002],
#  [2011062708155, '', 'Fangehåndboka 2003', 2003],
#  [2011062405052, 'Nord, Erik', 'Kruttrøyk &amp; fredspipe', 2004],
#  [2010032505074, '', 'Godkjenningskatalogen', 1999],
#  [2016110948137,
#   'Søvig, Karl Harald',
#   'Tvang overfor rusmiddelavhengige',
#   2004],
#  [2013073038010, '', 'Arbeidsmiljøloven', 2011],
#  [2016070608108, '', 'Psykisk helsevernloven med forskrifter', 2002],
#  [2011052008157,
#   'Borgerud, Ingeborg M.',
#   'Arbeidsmiljøloven 17. juni 2005 nr. 62',
#   2006],
#  [2014020348046, '', 'Barnevern 2009-2011', 2009],
#  [2008100104041, '', 'Smittevernloven', 2000],
#  [2012070505069,
#   'Rogstad, Daniel',
#   'Plan- og bygningsloven 14. juni 1985 nr. 77',
#   2006],
#  [2009042704055, '', 'Smittevernloven', 2000],
#  [2011022209032, '', 'Juridisk atlas', 2000],
#  [2008080600056, '', 'Jus i eldreomsorgen', 1998],
#  [2014070408068, '', 'Privatskolelova og forskrifter', 2008],
#  [2013062005079,
#   '',
#   'Kommunehelsetjenesteloven ; Sosialtjenesteloven ; Lov om sosiale tjenester i NAV',
#   2010],
#  [2015062408104,
#   'Andresen, Herbjørn',
#   'Tilgang til og videreformidling av helseopplysninger',
#   2010],
#  [2008091900001, 'Kramås, Petter', 'Tvang, makt og forsvarlighet', 1999],
#  [2009061704045, 'Engelsrud, Gerd', 'Styring og vern', 2006],
#  [2012071905062, '', 'Planlegging, vern og utbygging', 2006],
#  [2011082605002,
#   'Haugseth, Elisabeth Lier',
#   'Utsetting av genmodifiserte organismer',
#   2001],
#  [2011062406041,
#   'Rogstad, Daniel',
#   'Plan- og bygningsloven 14. juni 1985 nr. 77',
#   2003],
#  [2014022605036,
#   'Thune, Gro Hillestad',
#   'Introduksjon til menneskerettigheter innen psykisk helsefeltet [sic]',
#   2010],
#  [2010031803031, 'Vigerust, Elisabeth', 'Arbeid, barn og likestilling', 1998],
#  [2013071705043, 'Lundeberg, Ingrid Rindal', 'Grenser for tvang', 2009],
#  [2014021106064, 'Riedl, Tore Roald', 'Psykisk helsevernloven', 2008],
#  [2015051308253,
#   '',
#   'Domssamling i arbeidsrett: Domsavgjørelser og sivilombudsmannsuttalelser innen styringsrett, oppsigelser og avskjed',
#   2011],
#  [2013012108039, '', 'Opplæringslova og forskrifter', 2009],
#  [2011090108199, 'Hove, Harald', 'Barnevernloven 17. juli 1992 nr. 100', 2006],
#  [2009030900073,
#   'Hammerich, Peter',
#   'Kollektive og individuelle pensjonsavtaler',
#   2003],
#  [2015110908212, 'Stang, Elisabeth Gording', 'Det er barnets sak', 2007],
#  [2011091608197, '', 'Friskolelova og forskrifter', 2007],
#  [2013121908076,
#   'Syse, Aslak',
#   'Offentlige ytelser til personer med varige funksjonshemninger',
#   2002],
#  [2011041408118, '', 'Alkoholloven med kommentarer', 2001],
#  [2011050608025,
#   'Tufte, Siri Koller',
#   'Erstatningsansvar ved mobbing i den offentlige grunnskolen',
#   2004],
#  [2011062108025, 'Brynildsrud, Karsten', 'Barnevern og strafferett', 2007],
#  [2011081905070, 'Kjønstad, Asbjørn', 'Helserett', 2005],
#  [2008112500046,
#   'Søvig, Karl Harald',
#   'Tvang overfor gravide rusmiddelmisbrukere',
#   1999],
#  [2013080238012, 'Eikrem, Tove', 'Jungelhåndboka 2013', 2013],
#  [2014091709008, '', 'Lovsamling for helsepersonell', 2009],
#  [2011102408026, '', 'Idrett og juss', 2004],
#  [2009031804178,
#   '',
#   'Utkast til lov om innskuddspensjon i arbeidsforhold',
#   1999],
#  [2015081208064, 'Fougner, Jan', 'Endring i arbeidsforhold', 2007],
#  [2011060806126, 'Jenum, Marianne', 'statlige lederlønnsordningen', 2003],
#  [2009042304104, 'Befring, Anne Kjersti', 'Jus for leger', 2002],
#  [2008111800093, 'Befring, Anne Kjersti', 'Lov om helsepersonell', 2000],
#  [2011032908089, 'Larsen, Per Arne', 'Arbeidsmiljøloven', 2004],
#  [2015102808083, '', 'Barnehageloven og forskrifter', 2011],
#  [2011070705168, 'Tyrén, Carl Wilhelm', 'Plan- og bygningsloven', 2004],
#  [2011061708038, 'Andersen, Terje Gerhard', 'Avvikende tariffavtaler', 2007],
#  [2012032738058, '', 'Fangehåndboka 2007', 2007],
#  [2009032304030,
#   '',
#   'Psykisk helsevernloven og spesialisthelsetjenesteloven',
#   2000],
#  [2008090504064, '', 'Opplæringslova med forskrift', 1999],
#  [2014020306083, '', 'Praktisk miljørett', 2006],
#  [2012083008045,
#   'Riedl, Tore Roald',
#   'Rettsanvendelse innen det psykiske helsevern',
#   1999],
#  [2012020206103,
#   'Haga, Arne',
#   'Med barnet og saksbehandler til fylkesnemnda',
#   2001],
#  [2008091000007, 'Larsen, Per Arne', 'Arbeidsmiljøloven', 1999],
#  [2013043005069,
#   '',
#   'Lovsamling for styrere og pedagogiske ledere i barnehagen',
#   2008],
#  [2013060605038, '', 'Opplæringslova med forskrifter', 2006],
#  [2013020809043,
#   '',
#   'Lovsamling for styrere og pedagogiske ledere i barnehagen',
#   2010],
#  [2015070109137, '', 'Lovsamling for legekontoret', 2008],
#  [2008090904034,
#   'Vigerust, Elisabeth',
#   'Arbeidstakeres rettsstilling ved graviditet og omsorg',
#   1998],
#  [2011102806035, '', 'Ny lov om universiteter og høyskoler', 2003],
#  [2015112508024,
#   '',
#   'Spesialisthelsetjenesteloven og helseforetaksloven',
#   2006],
#  [2011040608085, '', 'Arbeidsrett', 2001],
#  [2014092906076,
#   'Øhrn, Hege Ingvoldstad',
#   'Rettigheter og plikter ved sykdom, svangerskap, fødsel og adopsjon',
#   2009],
#  [2012072405005, '', 'Innføring i byggereglene', 2006],
#  [2016022309004, '', 'Lovsamling for skoleledere', 2006],
#  [2014071808066, 'Dege, Jan Tormod', 'individuelle arbeidsrett', 2009],
#  [2011052605054,
#   '',
#   'Tilsattes rettigheter ved sykdom, fødsel, adopsjon m.m',
#   2001],
#  [2011081106014, 'Syse, Aslak', 'Psykisk helsevernloven', 2004],
#  [2010022500012, 'Kjønstad, Asbjørn', 'Innføring i trygderett', 1998],
#  [2011032208016, 'Hove, Harald', 'Barnevernloven 17. juli 1992 nr. 100', 2003],
#  [2013041806032, 'Ohnstad, Bente', 'Juss for helse- og sosialarbeidere', 2009],
#  [2014091609020, '', 'Lovsamling for skoleledere', 2011],
#  [2008080604043, '', 'Lov om universiteter og høgskoler', 1998],
#  [2012090408085, '', 'Obligatorisk tjenestepensjon', 2005],
#  [2013080608194, 'Kroken, Jørn', 'Bruk av tvang og makt', 2011],
#  [2013070205099, '', 'Materialsamling i arbeidsrett', 2003],
#  [2012072508032,
#   '',
#   'Váikkuhusčielggadusat plána- ja huksenlága mielde',
#   1998],
#  [2009073000063, '', 'Mer effektiv bygningslovgivning', 2003],
#  [2016030308040, '', 'Opplæringslova og forskrifter', 2013],
#  [2008110600054,
#   'Johansen, Thor-Erik',
#   'Inngåelse og avslutning av arbeidsforhold',
#   2001],
#  [2012120508105, '', 'Evaluering av bioteknologiloven', 2011],
#  [2008120100023, '', 'Lov om arbeidervern og arbeidsmiljø', 2001],
#  [2015071308197, 'Molven, Olav', 'Helse og jus', 2006],
#  [2013050606097, '', 'Psykisk helsevernloven med forskrifter', 2006],
#  [2013051406002, '', 'Sosialrett', 2000],
#  [2012090708212, '', 'Opplæringslova med forskrift', 2000],
#  [2008090200052, '', 'Administrasjon og forvaltning 1999', 1999],
#  [2014022605020, '', 'Plan og bygningsloven', 2009],
#  [2013090906068, '', 'Meglerprovisjon i forsikring', 2007],
#  [2011030108110, 'Jakhelln, Henning', 'Arbeidsrettslige studier', 2000],
#  [2013120206145, '', 'Plan- og bygningsloven og forskriftene i praksis', 2000],
#  [2011032908100, 'Schei, Andreas', '"Biologisk forurensning"', 2004],
#  [2011032108094, '', 'Aktuelle lover for helsetjenesten', 2005],
#  [2009072801135, 'Edvardsen, Hege Marie', 'Byggesaksreformen', 2004],
#  [2010031606056,
#   'Widme, Nils Ola',
#   'Nasjonal regulering av helse- og miljøspørsmål på områder som omfattes av et harmoniseringsdirektiv',
#   1999],
#  [2016071108022, '', 'Lovsamling for Den norske kirke', 2001],
#  [2013013108172,
#   '',
#   'Lov om arbeidsmiljø, arbeidstid og stillingsvern mv. (Arbeidsmiljøloven)',
#   2010],
#  [2008112004048, 'Helgeland, Geir', 'Opplæringslova', 2001],
#  [2008081504066,
#   '',
#   'Krav til forsvarlig virksomhet i primærhelsetjenesten',
#   1998],
#  [2010050503016, 'Stavang, Endre', 'Naborettens forurensningsansvar', 1999],
#  [2010060102039, 'Fougner, Jan', 'Arbeidsavtalen', 1999],
#  [2011100406106,
#   'Kittilsen, Heidi Quamme',
#   'Informasjonsflyten mellom hjem og skole',
#   2004],
#  [2013080908015, '', 'Juss for skoleledere', 2012],
#  [2011102608073,
#   'Befring, Anne Kjersti',
#   'Jus for jordmødre og sykepleiere',
#   2004],
#  [2011092608005, '', 'Kommunehelsetjenesteloven, sosialtjenesteloven', 2004],
#  [2011061608081,
#   'Hedlund, Mary-Ann',
#   'Likestillings- og diskrimineringslovene',
#   2008],
#  [2013081208089, 'Samset, Ingar', 'Kirkeloven § 15', 1999],
#  [2009061204001, 'Eikrem, Tove', 'Funksjonshemmedes rettigheter', 2002],
#  [2015111008083, 'Ottesen, Gunnar', 'Yrkes- og arbeidslovgivning', 2006],
#  [2011120206045, '', 'Informasjonssikkerhet', 2005],
#  [2011070506018, '', 'Lov om arbeidervern og arbeidsmiljø', 2004],
#  [2013071806193, 'Molven, Olav', 'Sykepleie og jus', 2009],
#  [2014081905074, 'Kjellevold, Alice', 'Retten til individuell plan', 2009],
#  [2011022808078, 'Jakhelln, Henning', 'Arbeidsrettslige studier', 2000],
#  [2009032504028,
#   'Sigurdsen, Randi Helene',
#   'Barn med funksjonshemninger og deres families rett til sosiale vernetiltak',
#   2000],
#  [2009022004048,
#   '',
#   'Bedre kommunal og regional planlegging etter plan- og bygningsloven II',
#   2003],
#  [2015102208382, '', 'Lovsamling for Den norske kirke', 2003],
#  [2015102108114, 'Dalheim, Tron', 'Sjømannsrett', 2008],
#  [2011080406076, '', 'Lov om barnehager med forskrifter', 2003],
#  [2008110600002,
#   'Finnesand, Torstein',
#   'Forskrift av 12. april 2000 om utslipp fra mindre avløpsanlegg',
#   2000],
#  [2009041400038, 'Gjone, Tor Aa.', 'Bedriftens personalhåndbok', 2002],
#  [2013050606079,
#   'Edvardsen, Åsmund',
#   'Betaling for beboere i institusjon',
#   2000],
#  [2012112206299, 'Skarning, Nicolay', 'Nedbemanning og sluttpakker', 2005],
#  [2010030304011, '', 'Hjelpetiltak - barnevernloven § 4-4', 1998],
#  [2008102904016,
#   'Gulbrandsen, Elisabeth',
#   'Rettigheter og plikter i læreforholdet',
#   2000],
#  [2011082908052, 'Aagaard, Erik C.', 'Bedriftens personalhåndbok', 2006],
#  [2009042904029, 'Andenæs, Kristian', 'Sosialtjenesteloven', 2002],
#  [2011032208024, 'Dege, Jan Tormod', 'Arbeidsrett', 2003],
#  [2016070448094, 'Arntzen, Andreas', 'Yrkesskadeforsikring', 2001],
#  [2009041704013, 'Ottesen, Gunnar', 'Yrkes- og arbeidslovgivning', 2000]]

# %%
len(nou)
# Out:
# 490

# %% [markdown]
# ## Konkordanser med URNer
#
# Kommandoen er *get_urnkonk()* som bruker URNer i stedet for metadata.

# %%
get_urnkonk('', {'urns':nou, 'before':18, 'after':18, 'size':14}, html=True)
# Out:
# <table></table>

# %% [markdown]
# ## URNer fra Bokhylla
#
# Gåt til http://nb.no/search og søk etter bøker. I søkefeltet legger du til ordet 'debugon' - da kommer resultatene med URN-er. Kopier hele siden (f.eks. med ctrl-a) og lim det inn i cellen under mellom de triple hermetegnene.
#
# Etter at teksten (det blir gjerne en hel del) er limt inn og cellen er aktivert, vil URNene ligge i variabelen bokhylla_urn, som så kan brukes sammen med *get_urnkonk()*.
#
# Har du noen URNer liggende i en Word-fil eller lignende, kan det også limes inn.

# %%
bokhylla_urn = """  """
bokhylla_urn = urn_from_text(bokhylla_urn)
bokhylla_urn

# %%
get_urnkonk('Ask',{
    'urns':bokhylla_urn
})
