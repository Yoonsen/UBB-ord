# %% [markdown]
# #  Clustre fra kollokasjoner
#
# The term collocation has traditionally been restricted to words that are juxtaposed together as phrases like “strong coffee”, “strict regime” or “eat dinner”. Here we take collocations to be realized as skipgrams, or as word pairs that simply cooccur within a context which in itself is a contiguous sequence of words, typically a paragraph or a window of n words around a given word. Juxtaposed collocates will also be part of the result set.
#
# The collocates for W is the words that are associated with W based on a measure of association. The purpose of such a measure for a word W (e.g. “democracy”) is to provide a means of collecting associated words in the discourses in which W occurs within C. Collocations can be viewed as collecting discourse markers for W, in the sense that the collocates are uttered (written or spoken) together with W. The collocates for W are computed via an association measure on the set of all cooccurrent words.

# %% [markdown]
# Start med å importere de kommandoene som trengs fra nbtext

# %%
import module_update

# %%
import nbtext as nb
from nbtext import cloud, get_urn, Cluster, Corpus
# %matplotlib inline

# %% [markdown]
# ### Definer et cluster for et ord over en gitt periode fra bøker eller aviser

# %%
exp=1.06

# %%
ord_cluster = Cluster(
    'biodiversitet',
    period=(1998, 2010), 
    before=5, 
    after=5, 
    corpus='avis',
    reference=100, 
    word_samples=100)

# %% [markdown]
# # Inspiser clustre
#
# Hvilke ord er knyttet til clustringsordet, er det variasjon i kontekst, trengs det mer data. Er resultatet tolkbart?

# %%
ord_cluster.
# Out:
# 'avis'

# %%
ord_cluster.cluster_set(top=250, exponent=1.06)
# Out:
# tap, mangfold, verdens, bevare, generasjoner, bevisene, bevaring, framtidens, tapet, internasjonale, økologi, innen, økologisk, professor, klima, marin, verdi, områder, Funksjonell, Barentshavets, arter, Universitetet, forvaltningsplaner, Sammenfatning, naturressurser, Christoffer, Schander, basert, kulturlandskap, bevegelse, vannressurser, biologisk, luftforurensning, global, natur, økt, kunnskap, klimaendringer, habitat, knapphet, forurensning, artenes, Stipendiat, akvakultur, produktive, økosystem, landbruksareal, konvensjonen, bærekraftig, energi, miljø, viss, knyttet, senter, zoologi, Begeistrede, metoder, fiskehelse, bevaringsbiologi, kvantitative, beundre, dynamikk, friluftsliv, barnebarna, klodens, menneskelig, biodiversitet, FN-konvensjonen, bemerkelsesverdige, naturens, funksjonell, genomforsking, beundrer, brøler, Søker, stabilitet, zootaksonomi, Bernkonvensjonen, biologer, oppvarming, klimaforskning, Boreselskapene, økosystemer, stanse, landbruk, miljøet, levende, helse, FNs, Ref, vekt, vedtatt, fisk, überørte, dømes, opprettholde, satsingen, kalles, klimapolitikk, Basmus, sjø, biologi, arealer, bunnforhold, utforske, temaer, bore, jordkvalitet, havforsuring, menes, BBF, forvalte, zoologisk, substansielt, skrek, Bevaring, artsmangfold, varierer, høy, nasjonalt, strid, truet, ressurser, Institutt, utvikling, stoppe, skog, krever, lavere, produksjon, hensyn, innan, Mannen, kyster, fiskeri, havforurensning, marinbiologi, Vedlegget, langtransport, mangfald, fornybare, hånd-i-, Verdensdag, lidenskap, Biologisk, kulturlandskapet, omgrepet, matematisk, energieffektivisering, rovdyr, lands, luft-, bekjempe, variasjon, Danmarks, marine, rekreasjon, kulturminner, variasjonen, generelt, okologisk, genetikk, betrakter, masterretninger, Julietta, jordbruk, Botanisk, organismer, botanikk, artsmangfoldet, ferskvannsfisk, forhandlingsleder, inndeles, rype, negative, foreleser, miljølære, Univer, Bansson, Sentrale, ekspert, kjemikalier, naturforskning, Bonn, Miljørettet, saksområder, HÅKON, Menneskeskapt, overvåking, ozon, paleoøkologi, evolusjon, Kabelvåg, Vitenskapsmuseet, Mexicos, erkjenne, undertegnet, klimaendringene, avhandling, rommer, Ciricius, måle, Trips, identitet, molekylærbiologi, Stikkord, jordas, bygder, måling, sitetet, Skoger, Cartagenaprotokollen, sanitærforhold, effekter, nordlige, klimaendringerog, kontinuerlig, Lofotakvariet, unntak, fremtidens, sann, hånd, nedgangen, beskyttelse, institutt, raskere, regel, ning, befolkningen, u-land, konsekvenser, Professor, europeisk, alternativ, Rio, kapital, viktige, medlem, oppgåver, ulike, betydning, sjette, utgjør, elg, rapport, internasjonalt, av, avtalen, forskning, internasjonal

# %%
ord_cluster_2.cluster_set(top=250, exponent=exp)
# Out:
# seg, over, bort, ut, lys, et, opp, den, blikk, ;, meg, de, ham, dem, tiden, inn, om, på, ned, eller, så, Det, tid, fra, men, ikke, deg, henne, for, mot, Jeg, Han, stein, sin, Men, har, noen, noe, etter, tilbake, alle, denne, oss, ~, hans, hadde, ved, mer, kan, vi, alt, igjen, da, dette, Hun, med, når, sine, I, slik, Og, glans, rundt, ', vinduet, nytt, sa, De, Den, bord, andre, armene, penger, gjennom, slenge, sig, litt, første, vil, før, skygge, ville, vrak, mye, [, fram, hele, kaste, hvis, sitt, ting, der, skal, ball, sammen, En, utfor, hodet, sjøen, ble, langt, frem, uten, blir, mellom, spyd, øynene, vekk, loss, enn, kunne, hverandre, gamle, paa, Da, {, kom, Så, halsen, bare, ta, la, få, disse, anker, Du, }, ballen, se, man, mens, rett, blår, overbord, mynt, under, uti, dei, gang, Vi, bakover, throw, må, livet, folk, også, vannet, sten, bli, år, mange, bak, hver, gikk, her, nye, liv, skulle, siden, 2., fengsel, fikk, gulvet, gi, nå, eneste, dør, min, din, hva, slynge, være, foran, hennes, stikka, slå, krone, deres, gå, eit, siste, bakken, ansiktet, barnet, måten, etc, skygger, steiner, selv, slikt, dag, tida, ha, tok, side, store, komme, sider, kommer, sette, spørsmål, dere, mine, a, omkring, annen, Hva, samme, vann, Når, seiv, all, ..., legge, På, heller, søppel, Dette, hvem, 3, fordi, føtter, Etter, gjøre, hvordan, luften, raskt, ingen, hesten, n, mig, ], Ikke, ganger, flere, havet, egen, lodd, tre, lenger, løpe, gjorde, helst, helt, spørsmålet, dine, kampen, b, hive, pa

# %% [markdown]
# # Tegn en ordsky
#
#
# kommandoen for å tegne en ordsky er *cloud()*. Argumentet kan være mange ting, så lenge det kobler et ord til et tall. Datarammer som består av en kolonne fungerer fint.

# %%
nb.cloud(ord_cluster.cluster_set(aslist=False, exponent=exp)[:150], background='black', file='marita_anje_gisle.jpg')
